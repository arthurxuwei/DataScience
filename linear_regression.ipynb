# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import torch
import torch.nn as nn
from torch.autograd import Variable
import random

# %%
x = torch.unsqueeze(torch.linspace(-1, 1, 100), dim=1)
y = 3*x + 10 + torch.rand(x.size())

# %%
plt.scatter(x.data, y.data)

# %%
class LinearRegression(nn.Module):
    def __init__(self):
        super(LinearRegression, self).__init__()
        self.linear = nn.Linear(1, 1)
    def forward(self, x):
        return self.linear(x)
model = LinearRegression()

# %%
cost = nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.01, momentum=0.9)

# %%
for epoch in range(100):
    y_pred = model(x)
    loss = cost(y_pred, y)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    if((epoch + 1) % 10 == 0):
        print("epoch{}, loss{}".format(epoch+1, loss.data))
# Out:
# epoch10, loss4.021034240722656
# epoch20, loss0.2084675133228302
# epoch30, loss0.7032538652420044
# epoch40, loss0.09317095577716827
# epoch50, loss0.1442849040031433
# epoch60, loss0.08765032142400742
# epoch70, loss0.08367440104484558
# epoch80, loss0.08180329203605652
# epoch90, loss0.07952680438756943
# epoch100, loss0.0797634944319725

# %%
plt.scatter(x.data, y.data)
plt.plot(x, model(x).data, color='red')

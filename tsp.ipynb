# %%
import numpy as np
import random
import math
from collections import namedtuple
import os
import time
from scipy.spatial import distance_matrix
import matplotlib.pyplot as plt
from sklearn.neighbors import NearestNeighbors
from scipy.sparse import csr_matrix
from scipy.sparse.csgraph import connected_components

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from scipy.signal import medfilt

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cpu')

# %%
def get_graph_mat(n=10, size=1):
    coords = np.random.uniform(size=(n, 2)) * size
    dist_mat = distance_matrix(coords, coords)
    return coords, dist_mat

def plot_graph(coords, mat):
    n = len(coords)
    plt.scatter(coords[:, 0], coords[:, 1], s=[50 for _ in range(n)])
    for i in range(n):
        for j in range(n):
            if j < i:
                plt.plot([coords[i, 0], coords[j, 0]], [coords[i, 1], coords[j, 1]], 'b', alpha=0.5)

coord, W_np = get_graph_mat(10)
plot_graph(coord, W_np)

# %%
State = namedtuple('State', ('W', 'coords', 'partial_solution'))
def state2tens(state):
    solution = set(state.partial_solution)
    sol_last_node = state.partial_solution[-1] if len(state.partial_solution) > 0 else None
    sol_first_node = state.partial_solution[0] if len(state.partial_solution) > 0 else None
    coords = state.coords
    nr_nodes = coords.shape[0]
    xv = [[(1 if i in solution else 0), (1 if i==sol_first_node else 0), (1 if i==sol_last_node else 0), coords[i,0], coords[i,1]] for i in range(nr_nodes)]

    return torch.tensor(xv, dtype=torch.float32, requires_grad=False, device=device)

# %%
class QNet(nn.Module):
    """ The neural net that will parameterize the function Q(s, a)
    
        The input is the state (containing the graph and visited nodes),
        and the output is a vector of size N containing Q(s, a) for each of the N actions a.
    """    
    
    def __init__(self, emb_dim, T=4):
        """ emb_dim: embedding dimension p
            T: number of iterations for the graph embedding
        """
        super(QNet, self).__init__()
        self.emb_dim = emb_dim
        self.T = T
        
        # We use 5 dimensions for representing the nodes' states:
        # * A binary variable indicating whether the node has been visited
        # * A binary variable indicating whether the node is the first of the visited sequence
        # * A binary variable indicating whether the node is the last of the visited sequence
        # * The (x, y) coordinates of the node.
        self.node_dim = 5
        
        # We can have an extra layer after theta_1 (for the sake of example to make the network deeper)
        nr_extra_layers_1 = 1
        
        # Build the learnable affine maps:
        self.theta1 = nn.Linear(self.node_dim, self.emb_dim, True)
        self.theta2 = nn.Linear(self.emb_dim, self.emb_dim, True)
        self.theta3 = nn.Linear(self.emb_dim, self.emb_dim, True)
        self.theta4 = nn.Linear(1, self.emb_dim, True)
        self.theta5 = nn.Linear(2*self.emb_dim, 1, True)
        self.theta6 = nn.Linear(self.emb_dim, self.emb_dim, True)
        self.theta7 = nn.Linear(self.emb_dim, self.emb_dim, True)
        
        self.theta1_extras = [nn.Linear(self.emb_dim, self.emb_dim, True) for _ in range(nr_extra_layers_1)]
        
    def forward(self, xv, Ws):
        # xv: The node features (batch_size, num_nodes, node_dim)
        # Ws: The graphs (batch_size, num_nodes, num_nodes)
        
        num_nodes = xv.shape[1]
        batch_size = xv.shape[0]
        
        # pre-compute 1-0 connection matrices masks (batch_size, num_nodes, num_nodes)
        conn_matrices = torch.where(Ws > 0, torch.ones_like(Ws), torch.zeros_like(Ws)).to(device)
        
        # Graph embedding
        # Note: we first compute s1 and s3 once, as they are not dependent on mu
        mu = torch.zeros(batch_size, num_nodes, self.emb_dim, device=device)
        s1 = self.theta1(xv)  # (batch_size, num_nodes, emb_dim)
        for layer in self.theta1_extras:
            s1 = layer(F.relu(s1))  # we apply the extra layer
        
        s3_1 = F.relu(self.theta4(Ws.unsqueeze(3)))  # (batch_size, nr_nodes, nr_nodes, emb_dim) - each "weigth" is a p-dim vector        
        s3_2 = torch.sum(s3_1, dim=1)  # (batch_size, nr_nodes, emb_dim) - the embedding for each node
        s3 = self.theta3(s3_2)  # (batch_size, nr_nodes, emb_dim)
        
        for t in range(self.T):
            s2 = self.theta2(conn_matrices.matmul(mu))    
            mu = F.relu(s1 + s2 + s3)
            
        """ prediction
        """
        # we repeat the global state (summed over nodes) for each node, 
        # in order to concatenate it to local states later
        global_state = self.theta6(torch.sum(mu, dim=1, keepdim=True).repeat(1, num_nodes, 1))
        
        local_action = self.theta7(mu)  # (batch_dim, nr_nodes, emb_dim)
            
        out = F.relu(torch.cat([global_state, local_action], dim=2))
        return self.theta5(out).squeeze(dim=2)

# %%
model = QNet(3, T=1).to(device)
coords, W_np = get_graph_mat(10)
W = torch.tensor(W_np, dtype=torch.float32, device=device)
xv = torch.rand((1, W.shape[0], 5)).to(device)
Ws = W.unsqueeze(0)
y = model(xv, Ws)
print('model output:{}'.format(y))
# Out:
# model output:tensor([[-2.3448, -2.3448, -2.3448, -2.3448, -2.3448, -2.3448, -2.3448, -2.3448,
#          -2.3448, -2.3448]], grad_fn=<SqueezeBackward1>)

# %%
class QFunction():
    def __init__(self, model, optimizer, lr_scheduler):
        self.model = model
        self.optimizer = optimizer
        self.lr_scheduler = lr_scheduler
        self.loss_fn = nn.MSELoss()

    def predict(self, state_tsr, W):
        with torch.no_grad():
            estimated_rewards = self.model(state_tsr.unsqueeze(0), W.unsqueeze(0))
        return estimated_rewards[0]
    
    def get_best_action(self, state_tsr, state):
        W = state.W
        estimated_rewards = self.predict(state_tsr, W)
        sorted_reward_idx = estimated_rewards.argsort(descending=True)

        solution = state.partial_solution
        already_in = set(solution)
        for i in sorted_reward_idx.tolist():
            if (len(solution)== 0 or W[solution[-1], i] > 0) and i not in already_in:
                return i, estimated_rewards[i].item()
    
    def batch_update(self, states_tsrs,  Ws, actios, targets):
        Ws_tsr = torch.stack(Ws).to(device)
        xv = torch.stack(states_tsrs).to(device)
        self.optimizer.zero_grad()
        estimated_rewards = self.model(xv, Ws_tsr)[range(len(actios)), actios]
        loss = self.loss_fn(estimated_rewards, torch.tensor(targets, device=device))
        loss_val = loss.item()

        loss.backward()
        self.optimizer.step()
        self.lr_scheduler.step()
        return loss_val

# %%
Experience = namedtuple('Experience', ('state', 'state_tsr', 'action', 'reward', 'next_state', 'next_state_tsr'))

class Memory(object):
    def __init__(self, capacity):
        self.capacity = capacity
        self.memory = []
        self.position = 0
        self.nr_inserts = 0
    
    def remember(self, experience):
        if len(self.memory) < self.capacity:
            self.memory.append(None)
        self.memory[self.position] = experience
        self.position = (self.position + 1) % self.capacity
        self.nr_inserts += 1
    
    def sample_batch(self, batch_size):
        return random.sample(self.memory, batch_size)
    
    def __len__(self):
        return min(self.nr_inserts, self.capacity)

# %%
def total_distance(solution, W):
    if len(solution) < 2:
        return 0
    total_dist = 0
    for i in range(len(solution)-1):
        total_dist += W[solution[i], solution[i+1]].item()

    if len(solution) == W.shape[0]:
        total_dist += W[solution[-1], solution[0]].item()
    return total_dist

def is_state_final(state):
    return len(state.partial_solution) == state.W.shape[0]

def get_next_neighbor_random(state):
    solution, W = state.partial_solution, state.W
    if len(solution) == 0:
        return random.choice(range(W.shape[0]))
    already_in = set(solution)
    candidates = list(filter(lambda x: x not in already_in, W[solution[-1]].nonzero()))
    if len(candidates) == 0:
        return None
    return random.choice(candidates).item()

# %%
SEED = 1

#Graph
NR_NODES = 10
EMBEDDING_DIMENSIONS = 5
EMBEDDING_ITERATIONS_T = 1

#Learning
NR_EPISODES = 4001
MEMORY_CAPACITY = 10000
N_STEP_QL = 2
BATCH_SIZE = 16

GAMMA = 0.9
INIT_LR = 5e-3
LR_DECAY_RATE= 1. - 2e-5

MIN_EPSILON = 0.1
EPSILON_DECAY_RATE = 6e-4

FOLDER_NAME = './models'

# %%
def init_model(fname=None):
    Q_net = QNet(EMBEDDING_DIMENSIONS, T=EMBEDDING_ITERATIONS_T).to(device)
    optimizer = optim.Adam(Q_net.parameters(), lr=INIT_LR)
    lr_scheduler = optim.lr_scheduler.ExponentialLR(optimizer, LR_DECAY_RATE)

    if fname is not None:
        checkpoint = torch.load(fname)
        Q_net.load_state_dict(checkpoint['model'])
        optimizer.load_state_dict(checkpoint['optimizer'])
        lr_scheduler.load_state_dict(checkpoint['lr_scheduler'])
    
    Q_func = QFunction(Q_net, optimizer, lr_scheduler)
    return Q_func, Q_net, optimizer, lr_scheduler

def checkpoint_model(model, optimizer, lr_scheduler, loss, episode, avg_length):
    if not os.path.exists(FOLDER_NAME):
        os.makedirs(FOLDER_NAME)
    
    fname = os.path.join(FOLDER_NAME, 'ep_{}'.format(episode))
    fname += '_length_{}'.format(avg_length)
    fname += '.tar'

    torch.save({
        'episode': episode,
        'model': model.state_dict(),
        'optimizer': optimizer.state_dict(),
        'lr_scheduler': lr_scheduler.state_dict(),
        'loss': loss,
        'avg_length': avg_length
    }, fname)

# %%
# seed everything for reproducible results first:
torch.manual_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)

# Create module, optimizer, LR scheduler, and Q-function
Q_func, Q_net, optimizer, lr_scheduler = init_model()

# Create memory
memory = Memory(MEMORY_CAPACITY)

# Storing metrics about training:
found_solutions = dict()  # episode --> (coords, W, solution)
losses = []
path_lengths = []

# keep track of median path length for model checkpointing
current_min_med_length = float('inf')

for episode in range(NR_EPISODES):
    # sample a new random graph
    coords, W_np = get_graph_mat(n=NR_NODES)
    W = torch.tensor(W_np, dtype=torch.float32, requires_grad=False, device=device)
    
    # current partial solution - a list of node index
    solution = [random.randint(0, NR_NODES-1)]
    
    # current state (tuple and tensor)
    current_state = State(partial_solution=solution, W=W, coords=coords)
    current_state_tsr = state2tens(current_state)
    
    # Keep track of some variables for insertion in replay memory:
    states = [current_state]
    states_tsrs = [current_state_tsr]  # we also keep the state tensors here (for efficiency)
    rewards = []
    actions = []
    
    # current value of epsilon
    epsilon = max(MIN_EPSILON, (1-EPSILON_DECAY_RATE)**episode)
    
    nr_explores = 0
    t = -1
    while not is_state_final(current_state):
        t += 1  # time step of this episode
        
        if epsilon >= random.random():
            # explore
            next_node = get_next_neighbor_random(current_state)
            nr_explores += 1
        else:
            # exploit
            next_node, est_reward = Q_func.get_best_action(current_state_tsr, current_state)
            if episode % 50 == 0:
                print('Ep {} | current sol: {} / next est reward: {}'.format(episode, solution, est_reward))
        
        next_solution = solution + [next_node]
        
        # reward observed for taking this step        
        reward = -(total_distance(next_solution, W) - total_distance(solution, W))
        
        next_state = State(partial_solution=next_solution, W=W, coords=coords)
        next_state_tsr = state2tens(next_state)
        
        # store rewards and states obtained along this episode:
        states.append(next_state)
        states_tsrs.append(next_state_tsr)
        rewards.append(reward)
        actions.append(next_node)
        
        # store our experience in memory, using n-step Q-learning:
        if len(solution) >= N_STEP_QL:
            memory.remember(Experience(state=states[-N_STEP_QL],
                                       state_tsr=states_tsrs[-N_STEP_QL],
                                       action=actions[-N_STEP_QL],
                                       reward=sum(rewards[-N_STEP_QL:]),
                                       next_state=next_state,
                                       next_state_tsr=next_state_tsr))
            
        if is_state_final(next_state):
            for n in range(1, N_STEP_QL):
                memory.remember(Experience(state=states[-n],
                                           state_tsr=states_tsrs[-n], 
                                           action=actions[-n], 
                                           reward=sum(rewards[-n:]), 
                                           next_state=next_state,
                                           next_state_tsr=next_state_tsr))
        
        # update state and current solution
        current_state = next_state
        current_state_tsr = next_state_tsr
        solution = next_solution
        
        # take a gradient step
        loss = None
        if len(memory) >= BATCH_SIZE and len(memory) >= 2000:
            experiences = memory.sample_batch(BATCH_SIZE)
            
            batch_states_tsrs = [e.state_tsr for e in experiences]
            batch_Ws = [e.state.W for e in experiences]
            batch_actions = [e.action for e in experiences]
            batch_targets = []
            
            for i, experience in enumerate(experiences):
                target = experience.reward
                if not is_state_final(experience.next_state):
                    _, best_reward = Q_func.get_best_action(experience.next_state_tsr, 
                                                            experience.next_state)
                    target += GAMMA * best_reward
                batch_targets.append(target)
                
            # print('batch targets: {}'.format(batch_targets))
            loss = Q_func.batch_update(batch_states_tsrs, batch_Ws, batch_actions, batch_targets)
            losses.append(loss)
            
            """ Save model when we reach a new low average path length
            """
            med_length = np.median(path_lengths[-100:])
            if med_length < current_min_med_length:
                current_min_med_length = med_length
                checkpoint_model(Q_net, optimizer, lr_scheduler, loss, episode, med_length)
                
    length = total_distance(solution, W)
    path_lengths.append(length)

    if episode % 10 == 0:
        print('Ep %d. Loss = %.3f / median length = %.3f / last = %.4f / epsilon = %.4f / lr = %.4f' % (
            episode, (-1 if loss is None else loss), np.median(path_lengths[-50:]), length, epsilon,
            Q_func.optimizer.param_groups[0]['lr']))
        found_solutions[episode] = (W.clone(), coords.copy(), [n for n in solution])
# Out:
# Ep 0. Loss = -1.000 / median length = 3.442 / last = 3.4421 / epsilon = 1.0000 / lr = 0.0050
# Ep 10. Loss = -1.000 / median length = 5.820 / last = 5.8141 / epsilon = 0.9940 / lr = 0.0050
# Ep 20. Loss = -1.000 / median length = 5.367 / last = 5.7750 / epsilon = 0.9881 / lr = 0.0050
# Ep 30. Loss = -1.000 / median length = 5.031 / last = 3.3189 / epsilon = 0.9822 / lr = 0.0050
# Ep 40. Loss = -1.000 / median length = 5.019 / last = 4.7237 / epsilon = 0.9763 / lr = 0.0050
# Ep 50. Loss = -1.000 / median length = 5.006 / last = 6.4173 / epsilon = 0.9704 / lr = 0.0050
# Ep 60. Loss = -1.000 / median length = 4.858 / last = 5.0481 / epsilon = 0.9646 / lr = 0.0050
# Ep 70. Loss = -1.000 / median length = 5.012 / last = 5.1142 / epsilon = 0.9589 / lr = 0.0050
# Ep 80. Loss = -1.000 / median length = 5.455 / last = 5.8020 / epsilon = 0.9531 / lr = 0.0050
# Ep 90. Loss = -1.000 / median length = 5.471 / last = 5.6243 / epsilon = 0.9474 / lr = 0.0050
# Ep 100 | current sol: [9, 3, 7, 9, 5, 6, 5, 7] / next est reward: 0.1497500091791153
# Ep 100. Loss = -1.000 / median length = 5.520 / last = 6.0140 / epsilon = 0.9417 / lr = 0.0050
# Ep 110. Loss = -1.000 / median length = 5.243 / last = 4.9832 / epsilon = 0.9361 / lr = 0.0050
# Ep 120. Loss = -1.000 / median length = 5.340 / last = 6.3126 / epsilon = 0.9305 / lr = 0.0050
# Ep 130. Loss = -1.000 / median length = 5.073 / last = 5.5949 / epsilon = 0.9249 / lr = 0.0050
# Ep 140. Loss = -1.000 / median length = 4.936 / last = 5.0285 / epsilon = 0.9194 / lr = 0.0050
# Ep 150 | current sol: [3, 1] / next est reward: 0.05874207615852356
# Ep 150. Loss = -1.000 / median length = 5.043 / last = 6.1149 / epsilon = 0.9139 / lr = 0.0050
# Ep 160. Loss = -1.000 / median length = 5.173 / last = 3.5437 / epsilon = 0.9084 / lr = 0.0050
# Ep 170. Loss = -1.000 / median length = 5.183 / last = 5.1835 / epsilon = 0.9030 / lr = 0.0050
# Ep 180. Loss = -1.000 / median length = 5.159 / last = 4.7792 / epsilon = 0.8976 / lr = 0.0050
# Ep 190. Loss = -1.000 / median length = 5.195 / last = 4.4819 / epsilon = 0.8922 / lr = 0.0050
# Ep 200. Loss = -1.000 / median length = 5.276 / last = 3.2613 / epsilon = 0.8869 / lr = 0.0050
# Ep 210. Loss = -1.000 / median length = 5.276 / last = 5.9003 / epsilon = 0.8816 / lr = 0.0050
# Ep 220. Loss = -1.000 / median length = 5.159 / last = 5.0191 / epsilon = 0.8763 / lr = 0.0050
# Ep 230. Loss = 0.737 / median length = 5.123 / last = 5.6055 / epsilon = 0.8711 / lr = 0.0050
# Ep 240. Loss = 0.883 / median length = 5.062 / last = 3.9631 / epsilon = 0.8659 / lr = 0.0050
# Ep 250 | current sol: [6, 1, 4, 0] / next est reward: -3.3682663440704346
# Ep 250 | current sol: [6, 1, 4, 0, 5, 6] / next est reward: -2.6648168563842773
# Ep 250 | current sol: [6, 1, 4, 0, 5, 6, 7] / next est reward: -2.152282238006592
# Ep 250. Loss = 0.533 / median length = 5.091 / last = 5.8223 / epsilon = 0.8607 / lr = 0.0050
# Ep 260. Loss = 0.398 / median length = 5.179 / last = 4.0178 / epsilon = 0.8555 / lr = 0.0050
# Ep 270. Loss = 0.473 / median length = 5.268 / last = 5.6952 / epsilon = 0.8504 / lr = 0.0050
# Ep 280. Loss = 0.885 / median length = 5.286 / last = 4.8836 / epsilon = 0.8453 / lr = 0.0049
# Ep 290. Loss = 0.378 / median length = 5.425 / last = 5.9636 / epsilon = 0.8403 / lr = 0.0049
# Ep 300 | current sol: [3, 5, 3, 1, 4, 5] / next est reward: -4.775146007537842
# Ep 300 | current sol: [3, 5, 3, 1, 4, 5, 2, 4, 2] / next est reward: -3.7121808528900146
# Ep 300. Loss = 0.696 / median length = 5.313 / last = 3.3954 / epsilon = 0.8352 / lr = 0.0049
# Ep 310. Loss = 0.304 / median length = 5.074 / last = 5.3414 / epsilon = 0.8302 / lr = 0.0049
# Ep 320. Loss = 1.326 / median length = 5.058 / last = 5.6150 / epsilon = 0.8253 / lr = 0.0049
# Ep 330. Loss = 0.503 / median length = 5.074 / last = 4.5388 / epsilon = 0.8203 / lr = 0.0049
# Ep 340. Loss = 1.056 / median length = 4.950 / last = 4.4498 / epsilon = 0.8154 / lr = 0.0049
# Ep 350 | current sol: [4, 9] / next est reward: -7.359542369842529
# Ep 350 | current sol: [4, 9, 3, 4, 7, 3, 2, 9] / next est reward: -5.214534759521484
# Ep 350. Loss = 1.296 / median length = 4.920 / last = 5.3390 / epsilon = 0.8105 / lr = 0.0049
# Ep 360. Loss = 1.333 / median length = 4.920 / last = 4.1621 / epsilon = 0.8057 / lr = 0.0049
# Ep 370. Loss = 0.877 / median length = 4.893 / last = 2.4268 / epsilon = 0.8009 / lr = 0.0049
# Ep 380. Loss = 0.657 / median length = 4.602 / last = 4.5509 / epsilon = 0.7961 / lr = 0.0049
# Ep 390. Loss = 1.243 / median length = 4.602 / last = 3.5627 / epsilon = 0.7913 / lr = 0.0049
# Ep 400 | current sol: [4, 7] / next est reward: -8.744950294494629
# Ep 400 | current sol: [4, 7, 5, 6, 4] / next est reward: -6.283961296081543
# Ep 400 | current sol: [4, 7, 5, 6, 4, 2, 4] / next est reward: -5.168010234832764
# Ep 400. Loss = 0.567 / median length = 4.602 / last = 3.8683 / epsilon = 0.7866 / lr = 0.0048
# Ep 410. Loss = 1.377 / median length = 4.607 / last = 3.2426 / epsilon = 0.7819 / lr = 0.0048
# Ep 420. Loss = 1.428 / median length = 4.834 / last = 5.3018 / epsilon = 0.7772 / lr = 0.0048
# Ep 430. Loss = 0.793 / median length = 4.856 / last = 4.3227 / epsilon = 0.7725 / lr = 0.0048
# Ep 440. Loss = 0.816 / median length = 4.898 / last = 3.5431 / epsilon = 0.7679 / lr = 0.0048
# Ep 450 | current sol: [5, 0, 8, 2] / next est reward: -7.577289581298828
# Ep 450. Loss = 0.643 / median length = 5.124 / last = 7.1462 / epsilon = 0.7633 / lr = 0.0048
# Ep 460. Loss = 0.217 / median length = 4.973 / last = 4.8198 / epsilon = 0.7588 / lr = 0.0048
# Ep 470. Loss = 1.811 / median length = 4.930 / last = 5.3732 / epsilon = 0.7542 / lr = 0.0048
# Ep 480. Loss = 1.547 / median length = 5.036 / last = 6.8533 / epsilon = 0.7497 / lr = 0.0048
# Ep 490. Loss = 1.044 / median length = 5.018 / last = 4.4460 / epsilon = 0.7452 / lr = 0.0048
# Ep 500 | current sol: [6, 7, 2, 9, 7, 0, 6, 1] / next est reward: -5.718990802764893
# Ep 500. Loss = 1.586 / median length = 4.824 / last = 5.2155 / epsilon = 0.7408 / lr = 0.0048
# Ep 510. Loss = 2.374 / median length = 4.827 / last = 6.1541 / epsilon = 0.7363 / lr = 0.0047
# Ep 520. Loss = 0.702 / median length = 4.827 / last = 4.9384 / epsilon = 0.7319 / lr = 0.0047
# Ep 530. Loss = 0.715 / median length = 4.717 / last = 3.7514 / epsilon = 0.7275 / lr = 0.0047
# Ep 540. Loss = 1.241 / median length = 4.476 / last = 3.2402 / epsilon = 0.7232 / lr = 0.0047
# Ep 550 | current sol: [6, 2, 4, 0] / next est reward: -5.800832271575928
# Ep 550 | current sol: [6, 2, 4, 0, 1] / next est reward: -4.507474422454834
# Ep 550 | current sol: [6, 2, 4, 0, 1, 3] / next est reward: -3.3493001461029053
# Ep 550. Loss = 0.327 / median length = 4.473 / last = 5.0518 / epsilon = 0.7189 / lr = 0.0047
# Ep 560. Loss = 0.431 / median length = 4.456 / last = 5.0035 / epsilon = 0.7146 / lr = 0.0047
# Ep 570. Loss = 0.638 / median length = 4.492 / last = 4.7937 / epsilon = 0.7103 / lr = 0.0047
# Ep 580. Loss = 1.217 / median length = 4.822 / last = 5.8359 / epsilon = 0.7060 / lr = 0.0047
# Ep 590. Loss = 0.766 / median length = 4.994 / last = 5.8981 / epsilon = 0.7018 / lr = 0.0047
# Ep 600 | current sol: [6, 8] / next est reward: -10.236736297607422
# Ep 600 | current sol: [6, 8, 3, 4] / next est reward: -7.337076187133789
# Ep 600 | current sol: [6, 8, 3, 4, 1] / next est reward: -5.950706958770752
# Ep 600 | current sol: [6, 8, 3, 4, 1, 0, 6] / next est reward: -4.237464427947998
# Ep 600. Loss = 0.462 / median length = 4.994 / last = 4.1816 / epsilon = 0.6976 / lr = 0.0047
# Ep 610. Loss = 0.541 / median length = 5.044 / last = 4.4260 / epsilon = 0.6934 / lr = 0.0047
# Ep 620. Loss = 0.966 / median length = 5.110 / last = 4.6423 / epsilon = 0.6893 / lr = 0.0047
# Ep 630. Loss = 1.757 / median length = 5.023 / last = 3.8060 / epsilon = 0.6852 / lr = 0.0046
# Ep 640. Loss = 1.473 / median length = 4.887 / last = 4.5957 / epsilon = 0.6811 / lr = 0.0046
# Ep 650 | current sol: [5] / next est reward: -10.493828773498535
# Ep 650 | current sol: [5, 1, 4, 3, 1, 4, 0, 3] / next est reward: -6.093670845031738
# Ep 650. Loss = 0.629 / median length = 4.980 / last = 4.8571 / epsilon = 0.6770 / lr = 0.0046
# Ep 660. Loss = 1.642 / median length = 4.980 / last = 6.8142 / epsilon = 0.6729 / lr = 0.0046
# Ep 670. Loss = 1.246 / median length = 5.011 / last = 5.3435 / epsilon = 0.6689 / lr = 0.0046
# Ep 680. Loss = 0.677 / median length = 4.807 / last = 4.2965 / epsilon = 0.6649 / lr = 0.0046
# Ep 690. Loss = 0.637 / median length = 4.839 / last = 5.6862 / epsilon = 0.6609 / lr = 0.0046
# Ep 700 | current sol: [0] / next est reward: -8.604373931884766
# Ep 700 | current sol: [0, 7] / next est reward: -7.621992588043213
# Ep 700 | current sol: [0, 7, 1] / next est reward: -6.766568660736084
# Ep 700 | current sol: [0, 7, 1, 6] / next est reward: -5.832668781280518
# Ep 700 | current sol: [0, 7, 1, 6, 3, 6, 4] / next est reward: -3.6855809688568115
# Ep 700 | current sol: [0, 7, 1, 6, 3, 6, 4, 5] / next est reward: -2.6586434841156006
# Ep 700. Loss = 0.636 / median length = 4.789 / last = 4.1563 / epsilon = 0.6570 / lr = 0.0046
# Ep 710. Loss = 0.752 / median length = 4.651 / last = 3.8250 / epsilon = 0.6530 / lr = 0.0046
# Ep 720. Loss = 1.166 / median length = 4.591 / last = 3.1176 / epsilon = 0.6491 / lr = 0.0046
# Ep 730. Loss = 0.583 / median length = 4.672 / last = 3.7794 / epsilon = 0.6452 / lr = 0.0046
# Ep 740. Loss = 0.548 / median length = 4.593 / last = 3.7369 / epsilon = 0.6414 / lr = 0.0046
# Ep 750 | current sol: [1] / next est reward: -9.08607006072998
# Ep 750 | current sol: [1, 6, 9, 7] / next est reward: -6.217118263244629
# Ep 750 | current sol: [1, 6, 9, 7, 3] / next est reward: -5.278287887573242
# Ep 750 | current sol: [1, 6, 9, 7, 3, 4, 7, 6] / next est reward: -4.076619625091553
# Ep 750. Loss = 0.679 / median length = 4.521 / last = 4.5736 / epsilon = 0.6375 / lr = 0.0045
# Ep 760. Loss = 2.032 / median length = 4.608 / last = 5.8079 / epsilon = 0.6337 / lr = 0.0045
# Ep 770. Loss = 0.576 / median length = 4.714 / last = 4.0546 / epsilon = 0.6299 / lr = 0.0045
# Ep 780. Loss = 0.760 / median length = 4.742 / last = 5.0970 / epsilon = 0.6262 / lr = 0.0045
# Ep 790. Loss = 0.681 / median length = 4.785 / last = 3.7231 / epsilon = 0.6224 / lr = 0.0045
# Ep 800 | current sol: [1, 4, 1, 5, 8, 6, 2] / next est reward: -3.866710901260376
# Ep 800 | current sol: [1, 4, 1, 5, 8, 6, 2, 3] / next est reward: -2.9689085483551025
# Ep 800. Loss = 1.156 / median length = 4.809 / last = 4.4998 / epsilon = 0.6187 / lr = 0.0045
# Ep 810. Loss = 0.905 / median length = 4.952 / last = 5.3142 / epsilon = 0.6150 / lr = 0.0045
# Ep 820. Loss = 0.618 / median length = 4.864 / last = 4.6110 / epsilon = 0.6113 / lr = 0.0045
# Ep 830. Loss = 0.228 / median length = 4.864 / last = 6.5208 / epsilon = 0.6077 / lr = 0.0045
# Ep 840. Loss = 0.684 / median length = 4.789 / last = 4.7379 / epsilon = 0.6040 / lr = 0.0045
# Ep 850 | current sol: [7, 3] / next est reward: -7.044770240783691
# Ep 850 | current sol: [7, 3, 6, 7, 9] / next est reward: -5.249470233917236
# Ep 850 | current sol: [7, 3, 6, 7, 9, 1, 2, 4, 3] / next est reward: -2.5894174575805664
# Ep 850. Loss = 0.264 / median length = 4.935 / last = 6.0445 / epsilon = 0.6004 / lr = 0.0045
# Ep 860. Loss = 0.754 / median length = 5.049 / last = 5.5160 / epsilon = 0.5968 / lr = 0.0045
# Ep 870. Loss = 1.242 / median length = 5.035 / last = 5.2808 / epsilon = 0.5932 / lr = 0.0044
# Ep 880. Loss = 0.612 / median length = 5.092 / last = 5.0627 / epsilon = 0.5897 / lr = 0.0044
# Ep 890. Loss = 0.689 / median length = 5.092 / last = 5.0051 / epsilon = 0.5862 / lr = 0.0044
# Ep 900 | current sol: [1, 0] / next est reward: -7.805899620056152
# Ep 900 | current sol: [1, 0, 5] / next est reward: -6.977856159210205
# Ep 900 | current sol: [1, 0, 5, 3, 1, 6, 0] / next est reward: -5.655881881713867
# Ep 900 | current sol: [1, 0, 5, 3, 1, 6, 0, 2, 3] / next est reward: -4.74357271194458
# Ep 900. Loss = 0.483 / median length = 4.932 / last = 4.6265 / epsilon = 0.5827 / lr = 0.0044
# Ep 910. Loss = 0.416 / median length = 4.608 / last = 3.7685 / epsilon = 0.5792 / lr = 0.0044
# Ep 920. Loss = 0.460 / median length = 4.625 / last = 4.4726 / epsilon = 0.5757 / lr = 0.0044
# Ep 930. Loss = 0.323 / median length = 4.511 / last = 4.8533 / epsilon = 0.5723 / lr = 0.0044
# Ep 940. Loss = 0.846 / median length = 4.564 / last = 5.1270 / epsilon = 0.5688 / lr = 0.0044
# Ep 950 | current sol: [8, 3, 6, 7, 4] / next est reward: -4.845895767211914
# Ep 950 | current sol: [8, 3, 6, 7, 4, 0] / next est reward: -3.8696436882019043
# Ep 950 | current sol: [8, 3, 6, 7, 4, 0, 5] / next est reward: -2.7567551136016846
# Ep 950 | current sol: [8, 3, 6, 7, 4, 0, 5, 9, 2] / next est reward: -1.647859811782837
# Ep 950. Loss = 0.563 / median length = 4.656 / last = 5.1197 / epsilon = 0.5654 / lr = 0.0044
# Ep 960. Loss = 0.299 / median length = 4.744 / last = 3.5537 / epsilon = 0.5620 / lr = 0.0044
# Ep 970. Loss = 0.238 / median length = 4.694 / last = 3.8787 / epsilon = 0.5587 / lr = 0.0044
# Ep 980. Loss = 0.660 / median length = 4.744 / last = 4.1455 / epsilon = 0.5553 / lr = 0.0044
# Ep 990. Loss = 0.679 / median length = 4.779 / last = 5.8458 / epsilon = 0.5520 / lr = 0.0044
# Ep 1000 | current sol: [8, 5, 7] / next est reward: -5.0296406745910645
# Ep 1000 | current sol: [8, 5, 7, 6, 4, 6] / next est reward: -3.727144479751587
# Ep 1000 | current sol: [8, 5, 7, 6, 4, 6, 3] / next est reward: -3.108689308166504
# Ep 1000. Loss = 0.160 / median length = 4.779 / last = 3.6802 / epsilon = 0.5487 / lr = 0.0043
# Ep 1010. Loss = 0.312 / median length = 4.901 / last = 5.1290 / epsilon = 0.5454 / lr = 0.0043
# Ep 1020. Loss = 0.771 / median length = 4.901 / last = 4.0681 / epsilon = 0.5422 / lr = 0.0043
# Ep 1030. Loss = 0.341 / median length = 4.840 / last = 4.5542 / epsilon = 0.5389 / lr = 0.0043
# Ep 1040. Loss = 0.598 / median length = 4.743 / last = 4.3185 / epsilon = 0.5357 / lr = 0.0043
# Ep 1050 | current sol: [2, 3, 0, 3, 0, 6] / next est reward: -4.616164207458496
# Ep 1050 | current sol: [2, 3, 0, 3, 0, 6, 1, 5, 2] / next est reward: -3.0506365299224854
# Ep 1050. Loss = 1.365 / median length = 4.748 / last = 3.9471 / epsilon = 0.5325 / lr = 0.0043
# Ep 1060. Loss = 0.834 / median length = 4.809 / last = 3.7035 / epsilon = 0.5293 / lr = 0.0043
# Ep 1070. Loss = 0.300 / median length = 4.874 / last = 4.5545 / epsilon = 0.5261 / lr = 0.0043
# Ep 1080. Loss = 0.648 / median length = 4.857 / last = 6.0252 / epsilon = 0.5230 / lr = 0.0043
# Ep 1090. Loss = 0.371 / median length = 4.731 / last = 4.2917 / epsilon = 0.5199 / lr = 0.0043
# Ep 1100 | current sol: [3] / next est reward: -6.139065265655518
# Ep 1100 | current sol: [3, 2] / next est reward: -5.621096134185791
# Ep 1100 | current sol: [3, 2, 0] / next est reward: -5.208919525146484
# Ep 1100 | current sol: [3, 2, 0, 5, 7] / next est reward: -4.142894268035889
# Ep 1100 | current sol: [3, 2, 0, 5, 7, 9] / next est reward: -3.2987751960754395
# Ep 1100 | current sol: [3, 2, 0, 5, 7, 9, 1] / next est reward: -2.4281985759735107
# Ep 1100 | current sol: [3, 2, 0, 5, 7, 9, 1, 6] / next est reward: -1.8466126918792725
# Ep 1100 | current sol: [3, 2, 0, 5, 7, 9, 1, 6, 8] / next est reward: -1.6812739372253418
# Ep 1100. Loss = 0.425 / median length = 5.020 / last = 5.9929 / epsilon = 0.5167 / lr = 0.0043
# Ep 1110. Loss = 0.431 / median length = 4.768 / last = 3.7707 / epsilon = 0.5137 / lr = 0.0043
# Ep 1120. Loss = 0.223 / median length = 4.611 / last = 4.1929 / epsilon = 0.5106 / lr = 0.0043
# Ep 1130. Loss = 0.433 / median length = 4.636 / last = 4.6486 / epsilon = 0.5075 / lr = 0.0042
# Ep 1140. Loss = 0.287 / median length = 4.636 / last = 4.5128 / epsilon = 0.5045 / lr = 0.0042
# Ep 1150 | current sol: [8, 0] / next est reward: -5.0681376457214355
# Ep 1150 | current sol: [8, 0, 3] / next est reward: -4.6153154373168945
# Ep 1150 | current sol: [8, 0, 3, 4] / next est reward: -4.107015132904053
# Ep 1150 | current sol: [8, 0, 3, 4, 1] / next est reward: -3.671138286590576
# Ep 1150 | current sol: [8, 0, 3, 4, 1, 6] / next est reward: -2.9129106998443604
# Ep 1150 | current sol: [8, 0, 3, 4, 1, 6, 9] / next est reward: -2.205737829208374
# Ep 1150 | current sol: [8, 0, 3, 4, 1, 6, 9, 5, 7] / next est reward: -1.206479787826538
# Ep 1150. Loss = 0.272 / median length = 4.540 / last = 3.6206 / epsilon = 0.5015 / lr = 0.0042
# Ep 1160. Loss = 0.327 / median length = 4.506 / last = 5.7570 / epsilon = 0.4985 / lr = 0.0042
# Ep 1170. Loss = 0.377 / median length = 4.506 / last = 5.4463 / epsilon = 0.4955 / lr = 0.0042
# Ep 1180. Loss = 0.333 / median length = 4.703 / last = 3.9238 / epsilon = 0.4925 / lr = 0.0042
# Ep 1190. Loss = 0.060 / median length = 4.857 / last = 5.3799 / epsilon = 0.4896 / lr = 0.0042
# Ep 1200 | current sol: [5, 4] / next est reward: -4.452878952026367
# Ep 1200 | current sol: [5, 4, 2] / next est reward: -4.1492600440979
# Ep 1200 | current sol: [5, 4, 2, 1] / next est reward: -3.8419442176818848
# Ep 1200 | current sol: [5, 4, 2, 1, 8] / next est reward: -3.5320913791656494
# Ep 1200 | current sol: [5, 4, 2, 1, 8, 0] / next est reward: -3.2212913036346436
# Ep 1200 | current sol: [5, 4, 2, 1, 8, 0, 6, 5] / next est reward: -2.896544933319092
# Ep 1200. Loss = 0.215 / median length = 4.720 / last = 3.8613 / epsilon = 0.4866 / lr = 0.0042
# Ep 1210. Loss = 0.304 / median length = 4.733 / last = 5.0126 / epsilon = 0.4837 / lr = 0.0042
# Ep 1220. Loss = 0.415 / median length = 4.615 / last = 4.3089 / epsilon = 0.4808 / lr = 0.0042
# Ep 1230. Loss = 0.233 / median length = 4.512 / last = 5.1007 / epsilon = 0.4780 / lr = 0.0042
# Ep 1240. Loss = 0.385 / median length = 4.500 / last = 4.8548 / epsilon = 0.4751 / lr = 0.0042
# Ep 1250 | current sol: [0, 6, 5] / next est reward: -3.884207010269165
# Ep 1250 | current sol: [0, 6, 5, 3, 7, 2] / next est reward: -2.309598445892334
# Ep 1250 | current sol: [0, 6, 5, 3, 7, 2, 9, 1] / next est reward: -1.3767274618148804
# Ep 1250 | current sol: [0, 6, 5, 3, 7, 2, 9, 1, 8] / next est reward: -1.3011454343795776
# Ep 1250. Loss = 0.207 / median length = 4.537 / last = 5.0612 / epsilon = 0.4723 / lr = 0.0042
# Ep 1260. Loss = 0.154 / median length = 4.523 / last = 4.2520 / epsilon = 0.4694 / lr = 0.0041
# Ep 1270. Loss = 0.528 / median length = 4.603 / last = 4.0497 / epsilon = 0.4666 / lr = 0.0041
# Ep 1280. Loss = 0.181 / median length = 4.809 / last = 3.4408 / epsilon = 0.4638 / lr = 0.0041
# Ep 1290. Loss = 0.406 / median length = 4.647 / last = 3.3210 / epsilon = 0.4611 / lr = 0.0041
# Ep 1300 | current sol: [2] / next est reward: -3.9278173446655273
# Ep 1300 | current sol: [2, 9] / next est reward: -3.6515040397644043
# Ep 1300 | current sol: [2, 9, 4, 0, 3] / next est reward: -2.3353493213653564
# Ep 1300 | current sol: [2, 9, 4, 0, 3, 5] / next est reward: -1.886081337928772
# Ep 1300 | current sol: [2, 9, 4, 0, 3, 5, 1] / next est reward: -1.5165977478027344
# Ep 1300 | current sol: [2, 9, 4, 0, 3, 5, 1, 6, 3] / next est reward: -1.2291152477264404
# Ep 1300. Loss = 0.211 / median length = 4.647 / last = 5.4242 / epsilon = 0.4583 / lr = 0.0041
# Ep 1310. Loss = 0.193 / median length = 4.844 / last = 5.5681 / epsilon = 0.4556 / lr = 0.0041
# Ep 1320. Loss = 0.413 / median length = 4.915 / last = 2.0752 / epsilon = 0.4528 / lr = 0.0041
# Ep 1330. Loss = 0.097 / median length = 4.864 / last = 4.2243 / epsilon = 0.4501 / lr = 0.0041
# Ep 1340. Loss = 0.181 / median length = 5.031 / last = 3.9756 / epsilon = 0.4474 / lr = 0.0041
# Ep 1350 | current sol: [3] / next est reward: -4.83218240737915
# Ep 1350 | current sol: [3, 8, 0, 6] / next est reward: -3.663990020751953
# Ep 1350 | current sol: [3, 8, 0, 6, 7] / next est reward: -3.0093283653259277
# Ep 1350 | current sol: [3, 8, 0, 6, 7, 4, 5, 2, 9] / next est reward: -1.9322125911712646
# Ep 1350. Loss = 0.205 / median length = 5.031 / last = 6.4471 / epsilon = 0.4447 / lr = 0.0041
# Ep 1360. Loss = 0.253 / median length = 4.858 / last = 4.9211 / epsilon = 0.4421 / lr = 0.0041
# Ep 1370. Loss = 0.334 / median length = 4.802 / last = 5.8470 / epsilon = 0.4394 / lr = 0.0041
# Ep 1380. Loss = 0.438 / median length = 4.844 / last = 6.6148 / epsilon = 0.4368 / lr = 0.0041
# Ep 1390. Loss = 0.171 / median length = 4.686 / last = 4.5915 / epsilon = 0.4342 / lr = 0.0041
# Ep 1400 | current sol: [5, 9] / next est reward: -4.421972751617432
# Ep 1400 | current sol: [5, 9, 8, 2, 7] / next est reward: -2.96730375289917
# Ep 1400 | current sol: [5, 9, 8, 2, 7, 1] / next est reward: -2.393368721008301
# Ep 1400 | current sol: [5, 9, 8, 2, 7, 1, 6, 9] / next est reward: -1.995614767074585
# Ep 1400 | current sol: [5, 9, 8, 2, 7, 1, 6, 9, 4] / next est reward: -1.573309302330017
# Ep 1400. Loss = 0.735 / median length = 4.818 / last = 4.9142 / epsilon = 0.4316 / lr = 0.0040
# Ep 1410. Loss = 0.229 / median length = 4.913 / last = 4.7729 / epsilon = 0.4290 / lr = 0.0040
# Ep 1420. Loss = 0.142 / median length = 4.814 / last = 4.0716 / epsilon = 0.4265 / lr = 0.0040
# Ep 1430. Loss = 0.093 / median length = 4.738 / last = 4.6095 / epsilon = 0.4239 / lr = 0.0040
# Ep 1440. Loss = 0.229 / median length = 4.768 / last = 3.3771 / epsilon = 0.4214 / lr = 0.0040
# Ep 1450 | current sol: [8, 6] / next est reward: -4.553465366363525
# Ep 1450 | current sol: [8, 6, 3] / next est reward: -4.217423439025879
# Ep 1450 | current sol: [8, 6, 3, 9] / next est reward: -3.8718132972717285
# Ep 1450 | current sol: [8, 6, 3, 9, 7] / next est reward: -3.446086883544922
# Ep 1450 | current sol: [8, 6, 3, 9, 7, 5] / next est reward: -2.8333568572998047
# Ep 1450 | current sol: [8, 6, 3, 9, 7, 5, 0, 9, 3] / next est reward: -2.1694421768188477
# Ep 1450. Loss = 0.208 / median length = 4.648 / last = 6.6454 / epsilon = 0.4188 / lr = 0.0040
# Ep 1460. Loss = 0.307 / median length = 4.620 / last = 5.4254 / epsilon = 0.4163 / lr = 0.0040
# Ep 1470. Loss = 0.219 / median length = 4.778 / last = 3.5120 / epsilon = 0.4138 / lr = 0.0040
# Ep 1480. Loss = 0.359 / median length = 4.926 / last = 4.9018 / epsilon = 0.4114 / lr = 0.0040
# Ep 1490. Loss = 0.218 / median length = 4.926 / last = 3.3691 / epsilon = 0.4089 / lr = 0.0040
# Ep 1500 | current sol: [6, 2] / next est reward: -4.691912651062012
# Ep 1500 | current sol: [6, 2, 7, 3, 0, 1] / next est reward: -2.2481582164764404
# Ep 1500 | current sol: [6, 2, 7, 3, 0, 1, 9] / next est reward: -1.8029588460922241
# Ep 1500 | current sol: [6, 2, 7, 3, 0, 1, 9, 5] / next est reward: -1.4081711769104004
# Ep 1500 | current sol: [6, 2, 7, 3, 0, 1, 9, 5, 4] / next est reward: -1.517723560333252
# Ep 1500. Loss = 0.155 / median length = 4.924 / last = 5.6557 / epsilon = 0.4065 / lr = 0.0040
# Ep 1510. Loss = 0.360 / median length = 4.883 / last = 3.2763 / epsilon = 0.4040 / lr = 0.0040
# Ep 1520. Loss = 0.201 / median length = 4.842 / last = 4.8756 / epsilon = 0.4016 / lr = 0.0040
# Ep 1530. Loss = 0.236 / median length = 4.885 / last = 5.5129 / epsilon = 0.3992 / lr = 0.0040
# Ep 1540. Loss = 0.344 / median length = 4.873 / last = 4.0867 / epsilon = 0.3968 / lr = 0.0039
# Ep 1550 | current sol: [9, 3] / next est reward: -4.3639445304870605
# Ep 1550 | current sol: [9, 3, 4] / next est reward: -3.985797643661499
# Ep 1550 | current sol: [9, 3, 4, 8, 9] / next est reward: -3.561984062194824
# Ep 1550 | current sol: [9, 3, 4, 8, 9, 6, 0] / next est reward: -2.3107504844665527
# Ep 1550. Loss = 0.244 / median length = 4.669 / last = 5.9089 / epsilon = 0.3944 / lr = 0.0039
# Ep 1560. Loss = 0.226 / median length = 4.634 / last = 6.4712 / epsilon = 0.3921 / lr = 0.0039
# Ep 1570. Loss = 0.089 / median length = 4.491 / last = 6.1865 / epsilon = 0.3897 / lr = 0.0039
# Ep 1580. Loss = 0.097 / median length = 4.507 / last = 4.4786 / epsilon = 0.3874 / lr = 0.0039
# Ep 1590. Loss = 0.173 / median length = 4.533 / last = 5.0948 / epsilon = 0.3851 / lr = 0.0039
# Ep 1600 | current sol: [9, 6, 9] / next est reward: -5.094566345214844
# Ep 1600 | current sol: [9, 6, 9, 2, 3, 9] / next est reward: -4.23425817489624
# Ep 1600 | current sol: [9, 6, 9, 2, 3, 9, 1] / next est reward: -3.756209135055542
# Ep 1600 | current sol: [9, 6, 9, 2, 3, 9, 1, 5] / next est reward: -3.0507946014404297
# Ep 1600. Loss = 0.463 / median length = 4.803 / last = 4.1291 / epsilon = 0.3828 / lr = 0.0039
# Ep 1610. Loss = 0.172 / median length = 4.840 / last = 4.6835 / epsilon = 0.3805 / lr = 0.0039
# Ep 1620. Loss = 0.585 / median length = 4.861 / last = 6.4923 / epsilon = 0.3782 / lr = 0.0039
# Ep 1630. Loss = 0.189 / median length = 4.850 / last = 5.5551 / epsilon = 0.3760 / lr = 0.0039
# Ep 1640. Loss = 0.342 / median length = 4.836 / last = 6.2276 / epsilon = 0.3737 / lr = 0.0039
# Ep 1650 | current sol: [9, 4, 5, 2] / next est reward: -4.411336421966553
# Ep 1650 | current sol: [9, 4, 5, 2, 8] / next est reward: -3.6364970207214355
# Ep 1650 | current sol: [9, 4, 5, 2, 8, 7] / next est reward: -2.9150469303131104
# Ep 1650 | current sol: [9, 4, 5, 2, 8, 7, 3] / next est reward: -2.157356023788452
# Ep 1650. Loss = 0.159 / median length = 4.819 / last = 5.6835 / epsilon = 0.3715 / lr = 0.0039
# Ep 1660. Loss = 0.239 / median length = 4.772 / last = 5.2850 / epsilon = 0.3692 / lr = 0.0039
# Ep 1670. Loss = 0.400 / median length = 4.704 / last = 4.9648 / epsilon = 0.3670 / lr = 0.0039
# Ep 1680. Loss = 0.344 / median length = 4.513 / last = 6.0529 / epsilon = 0.3648 / lr = 0.0038
# Ep 1690. Loss = 0.141 / median length = 4.523 / last = 6.0680 / epsilon = 0.3627 / lr = 0.0038
# Ep 1700 | current sol: [9] / next est reward: -4.8345947265625
# Ep 1700 | current sol: [9, 6] / next est reward: -4.5178608894348145
# Ep 1700 | current sol: [9, 6, 2] / next est reward: -4.181778907775879
# Ep 1700 | current sol: [9, 6, 2, 1] / next est reward: -3.853369951248169
# Ep 1700 | current sol: [9, 6, 2, 1, 5] / next est reward: -3.5272300243377686
# Ep 1700 | current sol: [9, 6, 2, 1, 5, 3, 8, 3, 9] / next est reward: -2.166970729827881
# Ep 1700. Loss = 0.809 / median length = 4.523 / last = 2.8785 / epsilon = 0.3605 / lr = 0.0038
# Ep 1710. Loss = 0.124 / median length = 4.561 / last = 5.6014 / epsilon = 0.3583 / lr = 0.0038
# Ep 1720. Loss = 0.377 / median length = 4.717 / last = 5.0611 / epsilon = 0.3562 / lr = 0.0038
# Ep 1730. Loss = 0.721 / median length = 4.854 / last = 3.4265 / epsilon = 0.3541 / lr = 0.0038
# Ep 1740. Loss = 0.349 / median length = 4.742 / last = 5.6326 / epsilon = 0.3519 / lr = 0.0038
# Ep 1750 | current sol: [2] / next est reward: -4.874943256378174
# Ep 1750 | current sol: [2, 9] / next est reward: -4.520238399505615
# Ep 1750 | current sol: [2, 9, 1, 4] / next est reward: -3.899956226348877
# Ep 1750 | current sol: [2, 9, 1, 4, 6, 5] / next est reward: -2.960538625717163
# Ep 1750 | current sol: [2, 9, 1, 4, 6, 5, 7] / next est reward: -2.195554733276367
# Ep 1750 | current sol: [2, 9, 1, 4, 6, 5, 7, 8] / next est reward: -2.007875680923462
# Ep 1750 | current sol: [2, 9, 1, 4, 6, 5, 7, 8, 3] / next est reward: -1.6935162544250488
# Ep 1750. Loss = 0.259 / median length = 4.700 / last = 4.4963 / epsilon = 0.3498 / lr = 0.0038
# Ep 1760. Loss = 0.252 / median length = 4.569 / last = 3.9191 / epsilon = 0.3477 / lr = 0.0038
# Ep 1770. Loss = 0.816 / median length = 4.738 / last = 4.7737 / epsilon = 0.3457 / lr = 0.0038
# Ep 1780. Loss = 0.780 / median length = 4.738 / last = 5.9919 / epsilon = 0.3436 / lr = 0.0038
# Ep 1790. Loss = 0.417 / median length = 4.769 / last = 4.9336 / epsilon = 0.3415 / lr = 0.0038
# Ep 1800 | current sol: [8] / next est reward: -5.367575645446777
# Ep 1800 | current sol: [8, 6, 8] / next est reward: -5.024473667144775
# Ep 1800 | current sol: [8, 6, 8, 5] / next est reward: -4.697432041168213
# Ep 1800 | current sol: [8, 6, 8, 5, 2] / next est reward: -4.539646625518799
# Ep 1800 | current sol: [8, 6, 8, 5, 2, 7] / next est reward: -4.097792148590088
# Ep 1800 | current sol: [8, 6, 8, 5, 2, 7, 9] / next est reward: -3.5480332374572754
# Ep 1800 | current sol: [8, 6, 8, 5, 2, 7, 9, 4] / next est reward: -2.659566879272461
# Ep 1800. Loss = 0.294 / median length = 4.789 / last = 4.0126 / epsilon = 0.3395 / lr = 0.0038
# Ep 1810. Loss = 0.628 / median length = 4.789 / last = 4.2229 / epsilon = 0.3375 / lr = 0.0038
# Ep 1820. Loss = 0.865 / median length = 4.586 / last = 5.0810 / epsilon = 0.3354 / lr = 0.0037
# Ep 1830. Loss = 0.225 / median length = 4.548 / last = 3.6789 / epsilon = 0.3334 / lr = 0.0037
# Ep 1840. Loss = 0.082 / median length = 4.596 / last = 6.3109 / epsilon = 0.3314 / lr = 0.0037
# Ep 1850 | current sol: [7] / next est reward: -5.619183540344238
# Ep 1850 | current sol: [7, 2] / next est reward: -5.3841471672058105
# Ep 1850 | current sol: [7, 2, 4, 3] / next est reward: -4.512716770172119
# Ep 1850 | current sol: [7, 2, 4, 3, 1, 0] / next est reward: -3.062678337097168
# Ep 1850 | current sol: [7, 2, 4, 3, 1, 0, 5] / next est reward: -2.6958351135253906
# Ep 1850 | current sol: [7, 2, 4, 3, 1, 0, 5, 9] / next est reward: -2.0305330753326416
# Ep 1850 | current sol: [7, 2, 4, 3, 1, 0, 5, 9, 8] / next est reward: -2.012845993041992
# Ep 1850. Loss = 0.530 / median length = 4.641 / last = 6.4212 / epsilon = 0.3294 / lr = 0.0037
# Ep 1860. Loss = 0.813 / median length = 4.471 / last = 4.3641 / epsilon = 0.3275 / lr = 0.0037
# Ep 1870. Loss = 0.209 / median length = 4.471 / last = 5.2258 / epsilon = 0.3255 / lr = 0.0037
# Ep 1880. Loss = 0.351 / median length = 4.812 / last = 6.8035 / epsilon = 0.3236 / lr = 0.0037
# Ep 1890. Loss = 0.400 / median length = 4.768 / last = 4.6959 / epsilon = 0.3216 / lr = 0.0037
# Ep 1900 | current sol: [7, 2] / next est reward: -3.830705404281616
# Ep 1900 | current sol: [7, 2, 6] / next est reward: -3.5943362712860107
# Ep 1900 | current sol: [7, 2, 6, 3] / next est reward: -3.389737367630005
# Ep 1900 | current sol: [7, 2, 6, 3, 5] / next est reward: -3.17165207862854
# Ep 1900 | current sol: [7, 2, 6, 3, 5, 4, 5] / next est reward: -2.810417652130127
# Ep 1900. Loss = 0.285 / median length = 4.583 / last = 3.4931 / epsilon = 0.3197 / lr = 0.0037
# Ep 1910. Loss = 0.253 / median length = 4.713 / last = 4.4516 / epsilon = 0.3178 / lr = 0.0037
# Ep 1920. Loss = 0.094 / median length = 4.713 / last = 4.2719 / epsilon = 0.3159 / lr = 0.0037
# Ep 1930. Loss = 0.154 / median length = 4.357 / last = 4.5703 / epsilon = 0.3140 / lr = 0.0037
# Ep 1940. Loss = 0.310 / median length = 4.273 / last = 5.3677 / epsilon = 0.3121 / lr = 0.0037
# Ep 1950 | current sol: [8, 3] / next est reward: -5.509846210479736
# Ep 1950 | current sol: [8, 3, 5] / next est reward: -5.3408050537109375
# Ep 1950 | current sol: [8, 3, 5, 4] / next est reward: -4.8465495109558105
# Ep 1950 | current sol: [8, 3, 5, 4, 6] / next est reward: -4.259295463562012
# Ep 1950 | current sol: [8, 3, 5, 4, 6, 1, 8] / next est reward: -3.7214372158050537
# Ep 1950 | current sol: [8, 3, 5, 4, 6, 1, 8, 7, 4] / next est reward: -3.4219443798065186
# Ep 1950. Loss = 0.358 / median length = 4.496 / last = 5.4393 / epsilon = 0.3103 / lr = 0.0037
# Ep 1960. Loss = 0.380 / median length = 4.594 / last = 4.5962 / epsilon = 0.3084 / lr = 0.0037
# Ep 1970. Loss = 0.894 / median length = 4.653 / last = 3.6918 / epsilon = 0.3066 / lr = 0.0036
# Ep 1980. Loss = 0.216 / median length = 4.793 / last = 3.9616 / epsilon = 0.3047 / lr = 0.0036
# Ep 1990. Loss = 0.742 / median length = 4.606 / last = 3.4469 / epsilon = 0.3029 / lr = 0.0036
# Ep 2000 | current sol: [4] / next est reward: -5.926370143890381
# Ep 2000 | current sol: [4, 8, 2] / next est reward: -5.396482944488525
# Ep 2000 | current sol: [4, 8, 2, 1] / next est reward: -4.942032814025879
# Ep 2000 | current sol: [4, 8, 2, 1, 5] / next est reward: -4.584238529205322
# Ep 2000 | current sol: [4, 8, 2, 1, 5, 3] / next est reward: -3.7826311588287354
# Ep 2000 | current sol: [4, 8, 2, 1, 5, 3, 0, 6] / next est reward: -1.9471533298492432
# Ep 2000. Loss = 0.442 / median length = 4.562 / last = 3.8154 / epsilon = 0.3011 / lr = 0.0036
# Ep 2010. Loss = 0.206 / median length = 4.562 / last = 5.0014 / epsilon = 0.2993 / lr = 0.0036
# Ep 2020. Loss = 0.295 / median length = 4.504 / last = 3.5917 / epsilon = 0.2975 / lr = 0.0036
# Ep 2030. Loss = 0.391 / median length = 4.474 / last = 4.0824 / epsilon = 0.2957 / lr = 0.0036
# Ep 2040. Loss = 0.251 / median length = 4.581 / last = 4.7102 / epsilon = 0.2939 / lr = 0.0036
# Ep 2050 | current sol: [6, 5] / next est reward: -6.5093994140625
# Ep 2050 | current sol: [6, 5, 8] / next est reward: -6.096950054168701
# Ep 2050 | current sol: [6, 5, 8, 7] / next est reward: -5.720455169677734
# Ep 2050 | current sol: [6, 5, 8, 7, 3] / next est reward: -5.141246795654297
# Ep 2050 | current sol: [6, 5, 8, 7, 3, 2, 4] / next est reward: -3.435053825378418
# Ep 2050 | current sol: [6, 5, 8, 7, 3, 2, 4, 1] / next est reward: -2.7249670028686523
# Ep 2050. Loss = 0.478 / median length = 4.615 / last = 6.4227 / epsilon = 0.2922 / lr = 0.0036
# Ep 2060. Loss = 0.351 / median length = 4.449 / last = 4.7849 / epsilon = 0.2904 / lr = 0.0036
# Ep 2070. Loss = 0.452 / median length = 4.545 / last = 4.5705 / epsilon = 0.2887 / lr = 0.0036
# Ep 2080. Loss = 0.262 / median length = 4.501 / last = 4.4825 / epsilon = 0.2870 / lr = 0.0036
# Ep 2090. Loss = 0.199 / median length = 4.574 / last = 4.6473 / epsilon = 0.2853 / lr = 0.0036
# Ep 2100 | current sol: [7, 2] / next est reward: -5.1356329917907715
# Ep 2100 | current sol: [7, 2, 1] / next est reward: -4.81815767288208
# Ep 2100 | current sol: [7, 2, 1, 4, 3] / next est reward: -4.00312614440918
# Ep 2100 | current sol: [7, 2, 1, 4, 3, 9, 8, 1] / next est reward: -2.294965982437134
# Ep 2100 | current sol: [7, 2, 1, 4, 3, 9, 8, 1, 5] / next est reward: -2.11944842338562
# Ep 2100. Loss = 0.268 / median length = 4.652 / last = 4.5686 / epsilon = 0.2835 / lr = 0.0036
# Ep 2110. Loss = 0.471 / median length = 4.665 / last = 4.6727 / epsilon = 0.2819 / lr = 0.0036
# Ep 2120. Loss = 1.062 / median length = 4.621 / last = 4.4519 / epsilon = 0.2802 / lr = 0.0036
# Ep 2130. Loss = 0.262 / median length = 4.665 / last = 4.9698 / epsilon = 0.2785 / lr = 0.0035
# Ep 2140. Loss = 0.167 / median length = 4.427 / last = 4.6178 / epsilon = 0.2768 / lr = 0.0035
# Ep 2150 | current sol: [5] / next est reward: -5.521446228027344
# Ep 2150 | current sol: [5, 2] / next est reward: -5.191129207611084
# Ep 2150 | current sol: [5, 2, 3] / next est reward: -4.815249443054199
# Ep 2150 | current sol: [5, 2, 3, 4] / next est reward: -4.5270233154296875
# Ep 2150 | current sol: [5, 2, 3, 4, 8] / next est reward: -4.199532985687256
# Ep 2150 | current sol: [5, 2, 3, 4, 8, 9] / next est reward: -4.005708694458008
# Ep 2150 | current sol: [5, 2, 3, 4, 8, 9, 1] / next est reward: -3.052021026611328
# Ep 2150 | current sol: [5, 2, 3, 4, 8, 9, 1, 0, 3] / next est reward: -2.142834424972534
# Ep 2150. Loss = 0.093 / median length = 4.312 / last = 3.9950 / epsilon = 0.2752 / lr = 0.0035
# Ep 2160. Loss = 0.165 / median length = 4.312 / last = 4.0347 / epsilon = 0.2735 / lr = 0.0035
# Ep 2170. Loss = 0.293 / median length = 4.326 / last = 3.9479 / epsilon = 0.2719 / lr = 0.0035
# Ep 2180. Loss = 0.481 / median length = 4.326 / last = 5.3391 / epsilon = 0.2703 / lr = 0.0035
# Ep 2190. Loss = 0.204 / median length = 4.508 / last = 4.6617 / epsilon = 0.2686 / lr = 0.0035
# Ep 2200 | current sol: [5] / next est reward: -4.740180492401123
# Ep 2200 | current sol: [5, 6] / next est reward: -4.530678749084473
# Ep 2200 | current sol: [5, 6, 0] / next est reward: -4.296408653259277
# Ep 2200 | current sol: [5, 6, 0, 4, 8] / next est reward: -3.6573007106781006
# Ep 2200 | current sol: [5, 6, 0, 4, 8, 3] / next est reward: -3.3535993099212646
# Ep 2200 | current sol: [5, 6, 0, 4, 8, 3, 7, 1] / next est reward: -2.112436056137085
# Ep 2200 | current sol: [5, 6, 0, 4, 8, 3, 7, 1, 2] / next est reward: -1.9916250705718994
# Ep 2200. Loss = 0.179 / median length = 4.555 / last = 3.5556 / epsilon = 0.2670 / lr = 0.0035
# Ep 2210. Loss = 0.382 / median length = 4.627 / last = 4.0211 / epsilon = 0.2654 / lr = 0.0035
# Ep 2220. Loss = 0.658 / median length = 4.678 / last = 3.2420 / epsilon = 0.2638 / lr = 0.0035
# Ep 2230. Loss = 0.312 / median length = 4.685 / last = 5.2795 / epsilon = 0.2623 / lr = 0.0035
# Ep 2240. Loss = 0.072 / median length = 4.757 / last = 4.9296 / epsilon = 0.2607 / lr = 0.0035
# Ep 2250 | current sol: [1] / next est reward: -4.738325595855713
# Ep 2250 | current sol: [1, 6, 9] / next est reward: -4.0873847007751465
# Ep 2250 | current sol: [1, 6, 9, 4] / next est reward: -3.841764211654663
# Ep 2250 | current sol: [1, 6, 9, 4, 0, 8] / next est reward: -3.1160902976989746
# Ep 2250 | current sol: [1, 6, 9, 4, 0, 8, 3] / next est reward: -2.626598358154297
# Ep 2250 | current sol: [1, 6, 9, 4, 0, 8, 3, 5] / next est reward: -1.9339661598205566
# Ep 2250 | current sol: [1, 6, 9, 4, 0, 8, 3, 5, 2] / next est reward: -1.3021388053894043
# Ep 2250. Loss = 0.382 / median length = 4.721 / last = 4.2093 / epsilon = 0.2591 / lr = 0.0035
# Ep 2260. Loss = 0.302 / median length = 4.595 / last = 3.7920 / epsilon = 0.2576 / lr = 0.0035
# Ep 2270. Loss = 0.304 / median length = 4.395 / last = 5.0851 / epsilon = 0.2560 / lr = 0.0035
# Ep 2280. Loss = 0.360 / median length = 4.431 / last = 6.4249 / epsilon = 0.2545 / lr = 0.0035
# Ep 2290. Loss = 0.123 / median length = 4.349 / last = 2.7562 / epsilon = 0.2530 / lr = 0.0034
# Ep 2300 | current sol: [9] / next est reward: -6.067168712615967
# Ep 2300 | current sol: [9, 3] / next est reward: -5.741640090942383
# Ep 2300 | current sol: [9, 3, 7, 8] / next est reward: -4.9400954246521
# Ep 2300 | current sol: [9, 3, 7, 8, 6, 9] / next est reward: -4.489873886108398
# Ep 2300 | current sol: [9, 3, 7, 8, 6, 9, 0, 2] / next est reward: -2.8582143783569336
# Ep 2300 | current sol: [9, 3, 7, 8, 6, 9, 0, 2, 5] / next est reward: -2.0566067695617676
# Ep 2300. Loss = 0.162 / median length = 4.497 / last = 6.8377 / epsilon = 0.2515 / lr = 0.0034
# Ep 2310. Loss = 0.330 / median length = 4.588 / last = 3.8069 / epsilon = 0.2500 / lr = 0.0034
# Ep 2320. Loss = 0.223 / median length = 4.497 / last = 2.9520 / epsilon = 0.2485 / lr = 0.0034
# Ep 2330. Loss = 0.223 / median length = 4.547 / last = 5.4008 / epsilon = 0.2470 / lr = 0.0034
# Ep 2340. Loss = 0.268 / median length = 4.717 / last = 4.8450 / epsilon = 0.2455 / lr = 0.0034
# Ep 2350 | current sol: [5] / next est reward: -4.532773494720459
# Ep 2350 | current sol: [5, 1] / next est reward: -4.274625301361084
# Ep 2350 | current sol: [5, 1, 8] / next est reward: -3.932095766067505
# Ep 2350 | current sol: [5, 1, 8, 4] / next est reward: -3.696002244949341
# Ep 2350 | current sol: [5, 1, 8, 4, 9] / next est reward: -3.4049251079559326
# Ep 2350 | current sol: [5, 1, 8, 4, 9, 6] / next est reward: -3.073354482650757
# Ep 2350 | current sol: [5, 1, 8, 4, 9, 6, 2] / next est reward: -2.4241702556610107
# Ep 2350. Loss = 0.145 / median length = 4.686 / last = 3.3644 / epsilon = 0.2440 / lr = 0.0034
# Ep 2360. Loss = 0.388 / median length = 4.780 / last = 3.3140 / epsilon = 0.2426 / lr = 0.0034
# Ep 2370. Loss = 0.257 / median length = 4.724 / last = 4.9960 / epsilon = 0.2411 / lr = 0.0034
# Ep 2380. Loss = 0.081 / median length = 4.686 / last = 4.1264 / epsilon = 0.2397 / lr = 0.0034
# Ep 2390. Loss = 0.147 / median length = 4.490 / last = 4.5474 / epsilon = 0.2383 / lr = 0.0034
# Ep 2400 | current sol: [7] / next est reward: -4.54641580581665
# Ep 2400 | current sol: [7, 4] / next est reward: -4.372691631317139
# Ep 2400 | current sol: [7, 4, 5] / next est reward: -4.19871711730957
# Ep 2400 | current sol: [7, 4, 5, 0] / next est reward: -3.950894832611084
# Ep 2400 | current sol: [7, 4, 5, 0, 9] / next est reward: -3.508772134780884
# Ep 2400 | current sol: [7, 4, 5, 0, 9, 3] / next est reward: -3.1283092498779297
# Ep 2400 | current sol: [7, 4, 5, 0, 9, 3, 6] / next est reward: -2.5417723655700684
# Ep 2400 | current sol: [7, 4, 5, 0, 9, 3, 6, 2] / next est reward: -1.9692859649658203
# Ep 2400 | current sol: [7, 4, 5, 0, 9, 3, 6, 2, 1] / next est reward: -2.2098264694213867
# Ep 2400. Loss = 0.176 / median length = 4.490 / last = 5.4394 / epsilon = 0.2368 / lr = 0.0034
# Ep 2410. Loss = 0.143 / median length = 4.486 / last = 6.1448 / epsilon = 0.2354 / lr = 0.0034
# Ep 2420. Loss = 0.134 / median length = 4.607 / last = 3.7867 / epsilon = 0.2340 / lr = 0.0034
# Ep 2430. Loss = 0.148 / median length = 4.614 / last = 5.1461 / epsilon = 0.2326 / lr = 0.0034
# Ep 2440. Loss = 0.259 / median length = 4.614 / last = 3.4171 / epsilon = 0.2312 / lr = 0.0034
# Ep 2450 | current sol: [8] / next est reward: -3.1362617015838623
# Ep 2450 | current sol: [8, 1] / next est reward: -2.9965567588806152
# Ep 2450 | current sol: [8, 1, 6, 8] / next est reward: -2.812140464782715
# Ep 2450 | current sol: [8, 1, 6, 8, 0] / next est reward: -2.720477819442749
# Ep 2450 | current sol: [8, 1, 6, 8, 0, 2] / next est reward: -2.5759201049804688
# Ep 2450 | current sol: [8, 1, 6, 8, 0, 2, 9, 8] / next est reward: -2.1221470832824707
# Ep 2450 | current sol: [8, 1, 6, 8, 0, 2, 9, 8, 7] / next est reward: -1.6541047096252441
# Ep 2450. Loss = 0.102 / median length = 4.541 / last = 4.8733 / epsilon = 0.2298 / lr = 0.0033
# Ep 2460. Loss = 0.113 / median length = 4.496 / last = 6.5992 / epsilon = 0.2284 / lr = 0.0033
# Ep 2470. Loss = 0.119 / median length = 4.221 / last = 3.2302 / epsilon = 0.2271 / lr = 0.0033
# Ep 2480. Loss = 0.062 / median length = 4.168 / last = 3.5880 / epsilon = 0.2257 / lr = 0.0033
# Ep 2490. Loss = 0.092 / median length = 4.202 / last = 5.1403 / epsilon = 0.2244 / lr = 0.0033
# Ep 2500 | current sol: [5] / next est reward: -2.070823907852173
# Ep 2500 | current sol: [5, 1, 8, 5] / next est reward: -2.0651724338531494
# Ep 2500 | current sol: [5, 1, 8, 5, 0] / next est reward: -2.013373613357544
# Ep 2500 | current sol: [5, 1, 8, 5, 0, 6, 5] / next est reward: -1.8466870784759521
# Ep 2500 | current sol: [5, 1, 8, 5, 0, 6, 5, 3] / next est reward: -1.546852707862854
# Ep 2500 | current sol: [5, 1, 8, 5, 0, 6, 5, 3, 4] / next est reward: -1.2182893753051758
# Ep 2500. Loss = 0.182 / median length = 4.485 / last = 5.0429 / epsilon = 0.2230 / lr = 0.0033
# Ep 2510. Loss = 0.113 / median length = 4.537 / last = 3.7413 / epsilon = 0.2217 / lr = 0.0033
# Ep 2520. Loss = 0.206 / median length = 4.735 / last = 5.6529 / epsilon = 0.2204 / lr = 0.0033
# Ep 2530. Loss = 0.150 / median length = 4.576 / last = 4.2874 / epsilon = 0.2190 / lr = 0.0033
# Ep 2540. Loss = 0.147 / median length = 4.746 / last = 5.5384 / epsilon = 0.2177 / lr = 0.0033
# Ep 2550 | current sol: [4, 9] / next est reward: -1.8915245532989502
# Ep 2550 | current sol: [4, 9, 3] / next est reward: -1.8577136993408203
# Ep 2550 | current sol: [4, 9, 3, 6] / next est reward: -1.7867823839187622
# Ep 2550 | current sol: [4, 9, 3, 6, 8] / next est reward: -1.8101372718811035
# Ep 2550 | current sol: [4, 9, 3, 6, 8, 0] / next est reward: -1.6024681329727173
# Ep 2550 | current sol: [4, 9, 3, 6, 8, 0, 2] / next est reward: -1.7373170852661133
# Ep 2550 | current sol: [4, 9, 3, 6, 8, 0, 2, 1] / next est reward: -1.3397961854934692
# Ep 2550 | current sol: [4, 9, 3, 6, 8, 0, 2, 1, 5] / next est reward: -1.0805766582489014
# Ep 2550. Loss = 0.081 / median length = 4.457 / last = 3.6319 / epsilon = 0.2164 / lr = 0.0033
# Ep 2560. Loss = 0.161 / median length = 4.563 / last = 3.2623 / epsilon = 0.2151 / lr = 0.0033
# Ep 2570. Loss = 0.140 / median length = 4.692 / last = 4.4869 / epsilon = 0.2139 / lr = 0.0033
# Ep 2580. Loss = 0.127 / median length = 4.533 / last = 3.3523 / epsilon = 0.2126 / lr = 0.0033
# Ep 2590. Loss = 0.115 / median length = 4.510 / last = 4.8698 / epsilon = 0.2113 / lr = 0.0033
# Ep 2600 | current sol: [3] / next est reward: -1.6701111793518066
# Ep 2600 | current sol: [3, 5] / next est reward: -1.656217336654663
# Ep 2600 | current sol: [3, 5, 1] / next est reward: -1.6300472021102905
# Ep 2600 | current sol: [3, 5, 1, 0] / next est reward: -1.5963331460952759
# Ep 2600 | current sol: [3, 5, 1, 0, 7] / next est reward: -1.5617876052856445
# Ep 2600 | current sol: [3, 5, 1, 0, 7, 9, 7] / next est reward: -1.4300521612167358
# Ep 2600 | current sol: [3, 5, 1, 0, 7, 9, 7, 2] / next est reward: -1.2967360019683838
# Ep 2600 | current sol: [3, 5, 1, 0, 7, 9, 7, 2, 6] / next est reward: -0.9333209991455078
# Ep 2600. Loss = 0.093 / median length = 4.510 / last = 3.4339 / epsilon = 0.2100 / lr = 0.0033
# Ep 2610. Loss = 0.156 / median length = 4.425 / last = 3.8705 / epsilon = 0.2088 / lr = 0.0033
# Ep 2620. Loss = 0.109 / median length = 4.425 / last = 5.3669 / epsilon = 0.2075 / lr = 0.0032
# Ep 2630. Loss = 0.273 / median length = 4.446 / last = 7.0337 / epsilon = 0.2063 / lr = 0.0032
# Ep 2640. Loss = 0.081 / median length = 4.469 / last = 4.5373 / epsilon = 0.2051 / lr = 0.0032
# Ep 2650 | current sol: [9] / next est reward: 0.7680611610412598
# Ep 2650 | current sol: [9, 7] / next est reward: 0.6341772079467773
# Ep 2650 | current sol: [9, 7, 4, 6] / next est reward: 0.3900078237056732
# Ep 2650 | current sol: [9, 7, 4, 6, 0, 4] / next est reward: 0.2356969118118286
# Ep 2650 | current sol: [9, 7, 4, 6, 0, 4, 1] / next est reward: 0.14629623293876648
# Ep 2650 | current sol: [9, 7, 4, 6, 0, 4, 1, 8, 6] / next est reward: 0.1233392059803009
# Ep 2650. Loss = 0.072 / median length = 4.517 / last = 3.8710 / epsilon = 0.2038 / lr = 0.0032
# Ep 2660. Loss = 0.299 / median length = 4.636 / last = 5.0752 / epsilon = 0.2026 / lr = 0.0032
# Ep 2670. Loss = 0.203 / median length = 4.564 / last = 6.0799 / epsilon = 0.2014 / lr = 0.0032
# Ep 2680. Loss = 0.131 / median length = 4.636 / last = 3.0719 / epsilon = 0.2002 / lr = 0.0032
# Ep 2690. Loss = 0.128 / median length = 4.529 / last = 3.1938 / epsilon = 0.1990 / lr = 0.0032
# Ep 2700 | current sol: [8] / next est reward: -2.8102948665618896
# Ep 2700 | current sol: [8, 1] / next est reward: -2.772540330886841
# Ep 2700 | current sol: [8, 1, 2, 5] / next est reward: -2.604456901550293
# Ep 2700 | current sol: [8, 1, 2, 5, 3, 2] / next est reward: -2.4134905338287354
# Ep 2700 | current sol: [8, 1, 2, 5, 3, 2, 9] / next est reward: -2.195512056350708
# Ep 2700 | current sol: [8, 1, 2, 5, 3, 2, 9, 4] / next est reward: -1.9809426069259644
# Ep 2700 | current sol: [8, 1, 2, 5, 3, 2, 9, 4, 0] / next est reward: -1.5820903778076172
# Ep 2700. Loss = 0.076 / median length = 4.644 / last = 4.7899 / epsilon = 0.1978 / lr = 0.0032
# Ep 2710. Loss = 0.154 / median length = 4.578 / last = 5.0302 / epsilon = 0.1966 / lr = 0.0032
# Ep 2720. Loss = 0.041 / median length = 4.514 / last = 4.0131 / epsilon = 0.1954 / lr = 0.0032
# Ep 2730. Loss = 0.153 / median length = 4.481 / last = 5.7316 / epsilon = 0.1943 / lr = 0.0032
# Ep 2740. Loss = 0.078 / median length = 4.446 / last = 3.1103 / epsilon = 0.1931 / lr = 0.0032
# Ep 2750 | current sol: [1] / next est reward: -1.6028633117675781
# Ep 2750 | current sol: [1, 0] / next est reward: -1.6084015369415283
# Ep 2750 | current sol: [1, 0, 6] / next est reward: -1.5779552459716797
# Ep 2750 | current sol: [1, 0, 6, 7, 0] / next est reward: -1.558701753616333
# Ep 2750 | current sol: [1, 0, 6, 7, 0, 8] / next est reward: -1.522212028503418
# Ep 2750 | current sol: [1, 0, 6, 7, 0, 8, 9] / next est reward: -1.34886634349823
# Ep 2750 | current sol: [1, 0, 6, 7, 0, 8, 9, 4] / next est reward: -1.1033947467803955
# Ep 2750 | current sol: [1, 0, 6, 7, 0, 8, 9, 4, 5] / next est reward: -0.8547489643096924
# Ep 2750. Loss = 0.143 / median length = 4.325 / last = 3.1236 / epsilon = 0.1920 / lr = 0.0032
# Ep 2760. Loss = 0.113 / median length = 4.356 / last = 4.3784 / epsilon = 0.1908 / lr = 0.0032
# Ep 2770. Loss = 0.056 / median length = 4.481 / last = 5.1415 / epsilon = 0.1897 / lr = 0.0032
# Ep 2780. Loss = 0.070 / median length = 4.642 / last = 4.9585 / epsilon = 0.1885 / lr = 0.0032
# Ep 2790. Loss = 0.119 / median length = 4.810 / last = 5.4241 / epsilon = 0.1874 / lr = 0.0031
# Ep 2800 | current sol: [8, 9] / next est reward: -0.8830878734588623
# Ep 2800 | current sol: [8, 9, 4] / next est reward: -0.8987680673599243
# Ep 2800 | current sol: [8, 9, 4, 7, 0, 2] / next est reward: -0.7902326583862305
# Ep 2800 | current sol: [8, 9, 4, 7, 0, 2, 3] / next est reward: -0.6131247282028198
# Ep 2800 | current sol: [8, 9, 4, 7, 0, 2, 3, 1] / next est reward: -0.3866424858570099
# Ep 2800. Loss = 0.115 / median length = 4.726 / last = 3.8498 / epsilon = 0.1863 / lr = 0.0031
# Ep 2810. Loss = 0.268 / median length = 4.811 / last = 5.5156 / epsilon = 0.1852 / lr = 0.0031
# Ep 2820. Loss = 0.084 / median length = 4.704 / last = 4.5047 / epsilon = 0.1841 / lr = 0.0031
# Ep 2830. Loss = 0.180 / median length = 4.585 / last = 4.8751 / epsilon = 0.1830 / lr = 0.0031
# Ep 2840. Loss = 0.112 / median length = 4.565 / last = 4.7843 / epsilon = 0.1819 / lr = 0.0031
# Ep 2850 | current sol: [5, 4] / next est reward: -1.3895877599716187
# Ep 2850 | current sol: [5, 4, 7] / next est reward: -1.4346944093704224
# Ep 2850 | current sol: [5, 4, 7, 8] / next est reward: -1.4182721376419067
# ...
# Ep 3250 | current sol: [7, 4, 3, 9, 2, 8, 0] / next est reward: -1.889650821685791
# Ep 3250 | current sol: [7, 4, 3, 9, 2, 8, 0, 6, 3] / next est reward: -1.4306998252868652
# Ep 3250. Loss = 0.109 / median length = 4.837 / last = 5.4127 / epsilon = 0.1422 / lr = 0.0029
# Ep 3260. Loss = 0.111 / median length = 4.781 / last = 5.4804 / epsilon = 0.1413 / lr = 0.0029
# Ep 3270. Loss = 0.230 / median length = 4.818 / last = 3.8732 / epsilon = 0.1405 / lr = 0.0029
# Ep 3280. Loss = 0.131 / median length = 4.754 / last = 4.9585 / epsilon = 0.1397 / lr = 0.0029
# Ep 3290. Loss = 0.055 / median length = 4.798 / last = 3.4723 / epsilon = 0.1388 / lr = 0.0029
# Ep 3300 | current sol: [5] / next est reward: -1.3738127946853638
# Ep 3300 | current sol: [5, 1] / next est reward: -1.4225528240203857
# Ep 3300 | current sol: [5, 1, 4] / next est reward: -1.4824554920196533
# Ep 3300 | current sol: [5, 1, 4, 2] / next est reward: -1.484714150428772
# Ep 3300 | current sol: [5, 1, 4, 2, 8] / next est reward: -1.4765841960906982
# Ep 3300 | current sol: [5, 1, 4, 2, 8, 9] / next est reward: -1.4513933658599854
# Ep 3300 | current sol: [5, 1, 4, 2, 8, 9, 6, 7] / next est reward: -0.8921103477478027
# Ep 3300 | current sol: [5, 1, 4, 2, 8, 9, 6, 7, 3] / next est reward: -0.5848962664604187
# Ep 3300. Loss = 0.112 / median length = 4.743 / last = 5.5961 / epsilon = 0.1380 / lr = 0.0029
# Ep 3310. Loss = 0.076 / median length = 4.697 / last = 4.1731 / epsilon = 0.1372 / lr = 0.0029
# Ep 3320. Loss = 0.206 / median length = 4.666 / last = 3.6054 / epsilon = 0.1363 / lr = 0.0029
# Ep 3330. Loss = 0.234 / median length = 4.666 / last = 5.0107 / epsilon = 0.1355 / lr = 0.0029
# Ep 3340. Loss = 0.074 / median length = 4.528 / last = 4.3657 / epsilon = 0.1347 / lr = 0.0029
# Ep 3350 | current sol: [5] / next est reward: -1.0907617807388306
# Ep 3350 | current sol: [5, 9] / next est reward: -1.1021064519882202
# Ep 3350 | current sol: [5, 9, 1] / next est reward: -1.1471939086914062
# Ep 3350 | current sol: [5, 9, 1, 7] / next est reward: -1.1819180250167847
# Ep 3350 | current sol: [5, 9, 1, 7, 2] / next est reward: -1.2212848663330078
# Ep 3350 | current sol: [5, 9, 1, 7, 2, 6] / next est reward: -1.236391305923462
# Ep 3350 | current sol: [5, 9, 1, 7, 2, 6, 4] / next est reward: -1.0248496532440186
# Ep 3350 | current sol: [5, 9, 1, 7, 2, 6, 4, 0] / next est reward: -0.7762600779533386
# Ep 3350 | current sol: [5, 9, 1, 7, 2, 6, 4, 0, 3] / next est reward: -0.43298977613449097
# Ep 3350. Loss = 0.119 / median length = 4.473 / last = 6.1151 / epsilon = 0.1339 / lr = 0.0028
# Ep 3360. Loss = 0.101 / median length = 4.447 / last = 4.9060 / epsilon = 0.1331 / lr = 0.0028
# Ep 3370. Loss = 0.114 / median length = 4.506 / last = 4.4708 / epsilon = 0.1323 / lr = 0.0028
# Ep 3380. Loss = 0.146 / median length = 4.444 / last = 3.7452 / epsilon = 0.1315 / lr = 0.0028
# Ep 3390. Loss = 0.092 / median length = 4.450 / last = 3.4633 / epsilon = 0.1307 / lr = 0.0028
# Ep 3400 | current sol: [8] / next est reward: -1.0568660497665405
# Ep 3400 | current sol: [8, 2, 7] / next est reward: -1.1739343404769897
# Ep 3400 | current sol: [8, 2, 7, 4, 1] / next est reward: -1.1786739826202393
# Ep 3400 | current sol: [8, 2, 7, 4, 1, 3] / next est reward: -1.0894676446914673
# Ep 3400 | current sol: [8, 2, 7, 4, 1, 3, 6] / next est reward: -0.9557771682739258
# Ep 3400 | current sol: [8, 2, 7, 4, 1, 3, 6, 0, 9] / next est reward: -0.6168324947357178
# Ep 3400. Loss = 0.062 / median length = 4.461 / last = 4.8348 / epsilon = 0.1299 / lr = 0.0028
# Ep 3410. Loss = 0.061 / median length = 4.516 / last = 5.8325 / epsilon = 0.1292 / lr = 0.0028
# Ep 3420. Loss = 0.136 / median length = 4.662 / last = 5.0097 / epsilon = 0.1284 / lr = 0.0028
# Ep 3430. Loss = 0.132 / median length = 4.828 / last = 5.0736 / epsilon = 0.1276 / lr = 0.0028
# Ep 3440. Loss = 0.074 / median length = 4.802 / last = 4.5889 / epsilon = 0.1269 / lr = 0.0028
# Ep 3450 | current sol: [9] / next est reward: -0.7075523734092712
# Ep 3450 | current sol: [9, 3] / next est reward: -0.783661425113678
# Ep 3450 | current sol: [9, 3, 1] / next est reward: -0.8610900044441223
# Ep 3450 | current sol: [9, 3, 1, 6] / next est reward: -0.910444974899292
# Ep 3450 | current sol: [9, 3, 1, 6, 8, 5] / next est reward: -1.0105383396148682
# Ep 3450 | current sol: [9, 3, 1, 6, 8, 5, 7] / next est reward: -0.8833812475204468
# Ep 3450 | current sol: [9, 3, 1, 6, 8, 5, 7, 0] / next est reward: -0.7907249331474304
# Ep 3450 | current sol: [9, 3, 1, 6, 8, 5, 7, 0, 4] / next est reward: -0.6650566458702087
# Ep 3450. Loss = 0.228 / median length = 4.783 / last = 5.2964 / epsilon = 0.1261 / lr = 0.0028
# Ep 3460. Loss = 0.126 / median length = 4.783 / last = 4.8776 / epsilon = 0.1254 / lr = 0.0028
# Ep 3470. Loss = 0.116 / median length = 4.821 / last = 3.1280 / epsilon = 0.1246 / lr = 0.0028
# Ep 3480. Loss = 0.085 / median length = 4.674 / last = 4.8226 / epsilon = 0.1239 / lr = 0.0028
# Ep 3490. Loss = 0.079 / median length = 4.821 / last = 4.8480 / epsilon = 0.1231 / lr = 0.0028
# Ep 3500 | current sol: [3] / next est reward: -0.6442499160766602
# Ep 3500 | current sol: [3, 1] / next est reward: -0.7262230515480042
# Ep 3500 | current sol: [3, 1, 5] / next est reward: -0.8227728605270386
# Ep 3500 | current sol: [3, 1, 5, 7] / next est reward: -0.9055001735687256
# Ep 3500 | current sol: [3, 1, 5, 7, 2, 3] / next est reward: -0.999294638633728
# Ep 3500 | current sol: [3, 1, 5, 7, 2, 3, 8] / next est reward: -1.016181230545044
# Ep 3500 | current sol: [3, 1, 5, 7, 2, 3, 8, 6] / next est reward: -0.9713670015335083
# Ep 3500 | current sol: [3, 1, 5, 7, 2, 3, 8, 6, 0] / next est reward: -0.7999134063720703
# Ep 3500. Loss = 0.124 / median length = 4.841 / last = 4.9703 / epsilon = 0.1224 / lr = 0.0028
# Ep 3510. Loss = 0.157 / median length = 4.821 / last = 6.3040 / epsilon = 0.1216 / lr = 0.0028
# Ep 3520. Loss = 0.135 / median length = 4.700 / last = 3.1014 / epsilon = 0.1209 / lr = 0.0028
# Ep 3530. Loss = 0.029 / median length = 4.787 / last = 3.9988 / epsilon = 0.1202 / lr = 0.0028
# Ep 3540. Loss = 0.144 / median length = 4.598 / last = 3.9366 / epsilon = 0.1195 / lr = 0.0028
# Ep 3550 | current sol: [5] / next est reward: -1.200668454170227
# Ep 3550 | current sol: [5, 9] / next est reward: -1.275841474533081
# Ep 3550 | current sol: [5, 9, 0, 8] / next est reward: -1.3954946994781494
# Ep 3550 | current sol: [5, 9, 0, 8, 3] / next est reward: -1.3813369274139404
# Ep 3550 | current sol: [5, 9, 0, 8, 3, 1, 6] / next est reward: -1.1650211811065674
# Ep 3550 | current sol: [5, 9, 0, 8, 3, 1, 6, 2] / next est reward: -1.1055079698562622
# Ep 3550 | current sol: [5, 9, 0, 8, 3, 1, 6, 2, 7] / next est reward: -0.773385763168335
# Ep 3550. Loss = 0.103 / median length = 4.541 / last = 5.7020 / epsilon = 0.1188 / lr = 0.0027
# Ep 3560. Loss = 0.052 / median length = 4.568 / last = 5.0724 / epsilon = 0.1181 / lr = 0.0027
# Ep 3570. Loss = 0.249 / median length = 4.568 / last = 4.6106 / epsilon = 0.1173 / lr = 0.0027
# Ep 3580. Loss = 0.098 / median length = 4.565 / last = 3.4095 / epsilon = 0.1166 / lr = 0.0027
# Ep 3590. Loss = 0.064 / median length = 4.767 / last = 5.5866 / epsilon = 0.1159 / lr = 0.0027
# Ep 3600 | current sol: [5, 2] / next est reward: -1.055509328842163
# Ep 3600 | current sol: [5, 2, 3] / next est reward: -1.1361815929412842
# Ep 3600 | current sol: [5, 2, 3, 6] / next est reward: -1.1996710300445557
# Ep 3600 | current sol: [5, 2, 3, 6, 9] / next est reward: -1.2423439025878906
# Ep 3600 | current sol: [5, 2, 3, 6, 9, 7] / next est reward: -1.234290599822998
# Ep 3600 | current sol: [5, 2, 3, 6, 9, 7, 8] / next est reward: -1.1210968494415283
# Ep 3600 | current sol: [5, 2, 3, 6, 9, 7, 8, 0] / next est reward: -0.9573916792869568
# Ep 3600. Loss = 0.175 / median length = 4.721 / last = 3.7836 / epsilon = 0.1153 / lr = 0.0027
# Ep 3610. Loss = 0.113 / median length = 4.827 / last = 4.5251 / epsilon = 0.1146 / lr = 0.0027
# Ep 3620. Loss = 0.091 / median length = 4.911 / last = 4.3869 / epsilon = 0.1139 / lr = 0.0027
# Ep 3630. Loss = 0.093 / median length = 5.142 / last = 4.4506 / epsilon = 0.1132 / lr = 0.0027
# Ep 3640. Loss = 0.075 / median length = 4.947 / last = 4.9981 / epsilon = 0.1125 / lr = 0.0027
# Ep 3650 | current sol: [2] / next est reward: -0.8357263803482056
# Ep 3650 | current sol: [2, 3, 4] / next est reward: -1.0121867656707764
# Ep 3650 | current sol: [2, 3, 4, 6] / next est reward: -1.1013990640640259
# Ep 3650 | current sol: [2, 3, 4, 6, 0] / next est reward: -1.1515684127807617
# Ep 3650 | current sol: [2, 3, 4, 6, 0, 7, 3] / next est reward: -1.1490345001220703
# Ep 3650 | current sol: [2, 3, 4, 6, 0, 7, 3, 1] / next est reward: -1.0498709678649902
# Ep 3650 | current sol: [2, 3, 4, 6, 0, 7, 3, 1, 9] / next est reward: -0.9230517148971558
# Ep 3650. Loss = 0.148 / median length = 4.929 / last = 5.0016 / epsilon = 0.1118 / lr = 0.0027
# Ep 3660. Loss = 0.113 / median length = 4.779 / last = 5.5060 / epsilon = 0.1112 / lr = 0.0027
# Ep 3670. Loss = 0.127 / median length = 4.686 / last = 4.1956 / epsilon = 0.1105 / lr = 0.0027
# Ep 3680. Loss = 0.044 / median length = 4.686 / last = 5.2809 / epsilon = 0.1098 / lr = 0.0027
# Ep 3690. Loss = 0.103 / median length = 4.739 / last = 6.3280 / epsilon = 0.1092 / lr = 0.0027
# Ep 3700 | current sol: [0] / next est reward: -1.2843905687332153
# Ep 3700 | current sol: [0, 1] / next est reward: -1.3368926048278809
# Ep 3700 | current sol: [0, 1, 5] / next est reward: -1.3704736232757568
# Ep 3700 | current sol: [0, 1, 5, 4] / next est reward: -1.4035801887512207
# Ep 3700 | current sol: [0, 1, 5, 4, 9] / next est reward: -1.4304776191711426
# Ep 3700 | current sol: [0, 1, 5, 4, 9, 2] / next est reward: -1.4467780590057373
# Ep 3700 | current sol: [0, 1, 5, 4, 9, 2, 6] / next est reward: -1.3620576858520508
# Ep 3700 | current sol: [0, 1, 5, 4, 9, 2, 6, 3] / next est reward: -1.153380274772644
# Ep 3700 | current sol: [0, 1, 5, 4, 9, 2, 6, 3, 7] / next est reward: -0.8817101716995239
# Ep 3700. Loss = 0.140 / median length = 4.884 / last = 5.3115 / epsilon = 0.1085 / lr = 0.0027
# Ep 3710. Loss = 0.105 / median length = 4.998 / last = 3.4241 / epsilon = 0.1079 / lr = 0.0027
# Ep 3720. Loss = 0.147 / median length = 5.064 / last = 5.3424 / epsilon = 0.1072 / lr = 0.0027
# Ep 3730. Loss = 0.235 / median length = 5.091 / last = 4.0891 / epsilon = 0.1066 / lr = 0.0027
# Ep 3740. Loss = 0.079 / median length = 5.008 / last = 4.5476 / epsilon = 0.1060 / lr = 0.0027
# Ep 3750 | current sol: [1] / next est reward: -0.6017175912857056
# Ep 3750 | current sol: [1, 4] / next est reward: -0.6924118995666504
# Ep 3750 | current sol: [1, 4, 3] / next est reward: -0.8035104870796204
# Ep 3750 | current sol: [1, 4, 3, 2, 0] / next est reward: -1.0270850658416748
# Ep 3750 | current sol: [1, 4, 3, 2, 0, 6] / next est reward: -1.041746735572815
# Ep 3750 | current sol: [1, 4, 3, 2, 0, 6, 5, 8] / next est reward: -0.7264344692230225
# Ep 3750. Loss = 0.131 / median length = 4.718 / last = 4.4951 / epsilon = 0.1053 / lr = 0.0026
# Ep 3760. Loss = 0.155 / median length = 4.686 / last = 5.4727 / epsilon = 0.1047 / lr = 0.0026
# Ep 3770. Loss = 0.120 / median length = 4.679 / last = 4.8359 / epsilon = 0.1041 / lr = 0.0026
# Ep 3780. Loss = 0.027 / median length = 4.710 / last = 4.8598 / epsilon = 0.1034 / lr = 0.0026
# Ep 3790. Loss = 0.194 / median length = 4.688 / last = 5.3930 / epsilon = 0.1028 / lr = 0.0026
# Ep 3800 | current sol: [6] / next est reward: -1.0006252527236938
# Ep 3800 | current sol: [6, 1] / next est reward: -1.101202368736267
# Ep 3800 | current sol: [6, 1, 2, 8] / next est reward: -1.2386913299560547
# Ep 3800 | current sol: [6, 1, 2, 8, 5, 1] / next est reward: -1.2765893936157227
# Ep 3800 | current sol: [6, 1, 2, 8, 5, 1, 4] / next est reward: -1.2370963096618652
# Ep 3800 | current sol: [6, 1, 2, 8, 5, 1, 4, 0] / next est reward: -1.1096160411834717
# Ep 3800. Loss = 0.131 / median length = 4.823 / last = 4.9537 / epsilon = 0.1022 / lr = 0.0026
# Ep 3810. Loss = 0.157 / median length = 4.726 / last = 5.4003 / epsilon = 0.1016 / lr = 0.0026
# Ep 3820. Loss = 0.046 / median length = 4.868 / last = 4.5724 / epsilon = 0.1010 / lr = 0.0026
# Ep 3830. Loss = 0.088 / median length = 4.745 / last = 3.3471 / epsilon = 0.1004 / lr = 0.0026
# Ep 3840. Loss = 0.098 / median length = 4.781 / last = 5.0936 / epsilon = 0.1000 / lr = 0.0026
# Ep 3850 | current sol: [0] / next est reward: -0.897055983543396
# Ep 3850 | current sol: [0, 7, 0] / next est reward: -0.9291213750839233
# Ep 3850 | current sol: [0, 7, 0, 5] / next est reward: -1.0009812116622925
# Ep 3850 | current sol: [0, 7, 0, 5, 8] / next est reward: -1.0770434141159058
# Ep 3850 | current sol: [0, 7, 0, 5, 8, 6] / next est reward: -1.1648740768432617
# Ep 3850 | current sol: [0, 7, 0, 5, 8, 6, 4] / next est reward: -1.2043862342834473
# Ep 3850 | current sol: [0, 7, 0, 5, 8, 6, 4, 2] / next est reward: -1.1464303731918335
# Ep 3850. Loss = 0.089 / median length = 4.820 / last = 4.8251 / epsilon = 0.1000 / lr = 0.0026
# Ep 3860. Loss = 0.185 / median length = 4.961 / last = 4.2541 / epsilon = 0.1000 / lr = 0.0026
# Ep 3870. Loss = 0.069 / median length = 5.068 / last = 4.4776 / epsilon = 0.1000 / lr = 0.0026
# Ep 3880. Loss = 0.160 / median length = 5.086 / last = 4.3739 / epsilon = 0.1000 / lr = 0.0026
# Ep 3890. Loss = 0.181 / median length = 5.087 / last = 4.6322 / epsilon = 0.1000 / lr = 0.0026
# Ep 3900 | current sol: [3] / next est reward: -1.1301145553588867
# Ep 3900 | current sol: [3, 6] / next est reward: -1.2000014781951904
# Ep 3900 | current sol: [3, 6, 8] / next est reward: -1.215409278869629
# Ep 3900 | current sol: [3, 6, 8, 1] / next est reward: -1.21830153465271
# Ep 3900 | current sol: [3, 6, 8, 1, 2, 1] / next est reward: -1.2223159074783325
# Ep 3900 | current sol: [3, 6, 8, 1, 2, 1, 7] / next est reward: -1.2246589660644531
# Ep 3900 | current sol: [3, 6, 8, 1, 2, 1, 7, 5] / next est reward: -1.1288301944732666
# Ep 3900 | current sol: [3, 6, 8, 1, 2, 1, 7, 5, 4] / next est reward: -0.9787561893463135
# Ep 3900. Loss = 0.160 / median length = 5.072 / last = 3.6962 / epsilon = 0.1000 / lr = 0.0026
# Ep 3910. Loss = 0.110 / median length = 4.999 / last = 5.9841 / epsilon = 0.1000 / lr = 0.0026
# Ep 3920. Loss = 0.083 / median length = 5.049 / last = 5.4236 / epsilon = 0.1000 / lr = 0.0026
# Ep 3930. Loss = 0.058 / median length = 4.868 / last = 4.4294 / epsilon = 0.1000 / lr = 0.0026
# Ep 3940. Loss = 0.055 / median length = 4.739 / last = 3.8297 / epsilon = 0.1000 / lr = 0.0026
# Ep 3950 | current sol: [1] / next est reward: -1.0164642333984375
# Ep 3950 | current sol: [1, 7] / next est reward: -1.1179184913635254
# Ep 3950 | current sol: [1, 7, 3] / next est reward: -1.2253086566925049
# Ep 3950 | current sol: [1, 7, 3, 8, 2] / next est reward: -1.372166633605957
# Ep 3950 | current sol: [1, 7, 3, 8, 2, 5, 6] / next est reward: -1.1850430965423584
# Ep 3950 | current sol: [1, 7, 3, 8, 2, 5, 6, 9] / next est reward: -1.024878978729248
# Ep 3950 | current sol: [1, 7, 3, 8, 2, 5, 6, 9, 0] / next est reward: -0.9078376293182373
# Ep 3950. Loss = 0.093 / median length = 4.760 / last = 4.3299 / epsilon = 0.1000 / lr = 0.0026
# Ep 3960. Loss = 0.078 / median length = 4.770 / last = 5.8241 / epsilon = 0.1000 / lr = 0.0026
# Ep 3970. Loss = 0.083 / median length = 4.716 / last = 3.4623 / epsilon = 0.1000 / lr = 0.0025
# Ep 3980. Loss = 0.115 / median length = 4.877 / last = 6.4476 / epsilon = 0.1000 / lr = 0.0025
# Ep 3990. Loss = 0.060 / median length = 4.838 / last = 3.9259 / epsilon = 0.1000 / lr = 0.0025
# Ep 4000 | current sol: [4] / next est reward: -0.6237428784370422
# Ep 4000 | current sol: [4, 0] / next est reward: -0.7283326387405396
# Ep 4000 | current sol: [4, 0, 3] / next est reward: -0.8510195016860962
# Ep 4000 | current sol: [4, 0, 3, 9] / next est reward: -0.9851097464561462
# Ep 4000 | current sol: [4, 0, 3, 9, 1] / next est reward: -1.1107208728790283
# Ep 4000 | current sol: [4, 0, 3, 9, 1, 7, 8] / next est reward: -0.9728920459747314
# Ep 4000 | current sol: [4, 0, 3, 9, 1, 7, 8, 2] / next est reward: -0.7657732367515564
# Ep 4000. Loss = 0.082 / median length = 4.878 / last = 5.0101 / epsilon = 0.1000 / lr = 0.0025

# %%
def _moving_avg(x, N=10):
    return np.convolve(np.array(x), np.ones(N,)/N, mode='valid')

plt.figure(figsize=(8,5))
plt.semilogy(_moving_avg(losses, N=100))
plt.ylabel('Loss')
plt.xlabel('training steps')

plt.figure(figsize=(8,5))
plt.plot(_moving_avg(path_lengths, N=100))
plt.ylabel('average length')
plt.xlabel('episode')
# Out:
# Text(0.5, 0, 'episode')

# %%
all_lengths_fnames = [f for f in os.listdir(FOLDER_NAME) if f.endswith('.tar')]
shortest_fname = sorted(all_lengths_fnames, key=lambda x: float(x.split('.tar')[0].split('_')[-1]))[0]
print('Shortest path found in file: {}'.format(shortest_fname.split('.tar')[0].split('_')[-1]))

Q_func, Q_net, optimizer, lr_scheduler = init_model(os.path.join(FOLDER_NAME, shortest_fname))

def plot_solution(coords, mat, solution):
    plt.scatter(coords[:, 0], coords[:, 1])
    n = len(coords)
    for i in range(n-1):
        i, next_i = solution[i], solution[i+1]
        plt.plot([coords[i, 0], coords[next_i, 0]], [coords[i, 1], coords[next_i, 1]], 'k', lw=2, alpha=0.8)
    
    i, next_i = solution[-1], solution[0]
    plt.plot([coords[i, 0], coords[next_i, 0]], [coords[i, 1], coords[next_i, 1]], 'k', lw=2, alpha=0.8)
    plt.plot(coords[solution[0], 0], coords[solution[0], 1], 'x', markersize=10)

NR_NODES = 10
for sample in range(10):
    coords, W_np = get_graph_mat(n=NR_NODES)
    W = torch.tensor(W_np, dtype=torch.float32, requires_grad=False, device=device)
    solution = [random.randint(0, NR_NODES-1)]
    current_state = State(partial_solution=solution, W=W, coords=coords)
    current_state_tsr = state2tens(current_state)
    while not is_state_final(current_state):
        next_node, est_reward = Q_func.get_best_action(current_state_tsr, current_state)
        solution = solution + [next_node]
        current_state = State(partial_solution=solution, W=W, coords=coords)
        current_state_tsr = state2tens(current_state)
    
    plt.figure()
    plot_solution(coords, W_np, solution)
    plt.title('model / len = {}'.format(total_distance(solution, W_np)))

    plt.figure()
    random_solution = list(range(NR_NODES))
    plot_solution(coords, W_np, random_solution)
    plt.title('random / len = {}'.format(total_distance(random_solution, W_np)))
# Out:
# Shortest path found in file: 4.352989889681339
